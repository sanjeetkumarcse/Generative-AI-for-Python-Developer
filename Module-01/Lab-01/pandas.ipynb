# %% [markdown]
# ## Import Libraries
# - A library or a Python built-in module is a bundle of features that add new functionality.
# - Libraries are not imported by default to save memory -- use them as you need them.
# - Libraries and modules must be imported into each project (the Jupyter Notebook)
# - Import a library with the **`import`** keyword followed by the library name:
# - Libraries can be assigned an alias, or an alternate name. Aliases are optional.
# - An alias reduces the amount of characters a user has to type when referencing a library.
# - An alias can have any name; the community standard for `pandas` is `pd`.
# - Follow the `import` statement with the `as` keyword and the alias (no quotes)
# - Multiple libraries can be imported in a single cell

# %% [markdown]
# ## Introduction to pandas
# - **Pandas** is a data analysis library built on top of the Python programming language.
# - The `pandas` library is built on top of the `numpy` library (Numerical Python)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DataFrames
# - A **DataFrame** is a 2-dimensional table consisting of rows and columns.
# - Pandas uses a `NaN` designation for cells that have a missing value. It is short for "not a number". Most operations on `NaN` values will produce `NaN` values.
# - Pandas assigns an index position/label to each **DataFrame** row.

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba.head(n=1)
# Out:
#          Name           Team Position Height  Weight    College     Salary
# 0  Saddiq Bey  Atlanta Hawks        F    6-7   215.0  Villanova  4556983.0

# %%
nba.head(8)
# Out:
#                 Name           Team Position Height  Weight           College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0         Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0        Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0          Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0       Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0          Maryland
# 5      Trent Forrest  Atlanta Hawks        G    6-4   210.0     Florida State
# 6         AJ Griffin  Atlanta Hawks        F    6-6   220.0              Duke
# 7     Mouhamed Gueye  Atlanta Hawks        F   6-11   210.0  Washington State
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0
# 5    508891.0
# 6   3712920.0
# 7   1119563.0

# %%
nba.tail()
# Out:
#                  Name                Team Position Height  Weight  \
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590      Delon Wright  Washington Wizards        G    6-5   185.0
# 591               NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN

# %%
nba.tail(n=7)
# Out:
#                  Name                Team Position Height  Weight  \
# 585    Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586      Jordan Poole  Washington Wizards        G    6-4   194.0
# 587      Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588     Landry Shamet  Washington Wizards        G    6-4   190.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590      Delon Wright  Washington Wizards        G    6-5   185.0
# 591               NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 585         Oregon    559782.0
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN

# %%
nba.tail(1)
# Out:
#     Name Team Position Height  Weight College  Salary
# 591  NaN  NaN      NaN    NaN     NaN     NaN     NaN

# %%
nba.index
# Out:
# RangeIndex(start=0, stop=592, step=1)

# %%
nba.values
# Out:
# array([['Saddiq Bey', 'Atlanta Hawks', 'F', ..., 215.0, 'Villanova',
#         4556983.0],
#        ['Bogdan Bogdanovic', 'Atlanta Hawks', 'G', ..., 225.0,
#         'Fenerbahce', 18700000.0],
#        ['Kobe Bufkin', 'Atlanta Hawks', 'G', ..., 195.0, 'Michigan',
#         4094244.0],
#        ...,
#        ['Tristan Vukcevic', 'Washington Wizards', 'F', ..., 220.0,
#         'Real Madrid', nan],
#        ['Delon Wright', 'Washington Wizards', 'G', ..., 185.0, 'Utah',
#         8195122.0],
#        [nan, nan, nan, ..., nan, nan, nan]], shape=(592, 7), dtype=object)

# %%
nba.shape
# Out:
# (592, 7)

# %%
nba.dtypes
# Out:
# Name         object
# Team         object
# Position     object
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
nba.columns
# Out:
# Index(['Name', 'Team', 'Position', 'Height', 'Weight', 'College', 'Salary'], dtype='object')

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=592, step=1),
#  Index(['Name', 'Team', 'Position', 'Height', 'Weight', 'College', 'Salary'], dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 32.5+ KB

# %% [markdown]
# ## Differences between Shared Methods
# - The `sum` method adds a **Series's** values.
# - On a **DataFrame**, the `sum` method defaults to adding the values by traversing the index (row values).
# - The `axis` parameter customizes the direction that we add across. Pass `"columns"` or `1` to add "across" the columns.

# %%
revenue = pd.read_csv("revenue.csv", index_col="Date")
revenue
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/26        985          122    499
# 1/2/26        738          788    534
# 1/3/26         14           20    933
# 1/4/26        730          904    885
# 1/5/26        114           71    253
# 1/6/26        936          502    497
# 1/7/26        123          996    115
# 1/8/26        935          492    886
# 1/9/26        846          954    823
# 1/10/26        54          285    216

# %%
revenue.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 1/1/26 to 1/10/26
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   New York     10 non-null     int64
#  1   Los Angeles  10 non-null     int64
#  2   Miami        10 non-null     int64
# dtypes: int64(3)
# memory usage: 320.0+ bytes

# %%
revenue.sum()
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis="index")
#revenue.sum(axis=0)
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
revenue.sum(axis="columns")
#revenue.sum(axis=1)
# Out:
# Date
# 1/1/26     1606
# 1/2/26     2060
# 1/3/26      967
# 1/4/26     2519
# 1/5/26      438
# 1/6/26     1935
# 1/7/26     1234
# 1/8/26     2313
# 1/9/26     2623
# 1/10/26     555
# dtype: int64

# %%
revenue.sum(axis="columns").sum()
# Out:
# np.int64(16250)

# %% [markdown]
# ## Select One Column from a DataFrame
# - We can use attribute syntax (`df.column_name`) to select a column from a **DataFrame**. The syntax will not work if the column name has spaces.
# - We can also use square bracket syntax (`df["column name"]`) which will work for any column name.
# - Pandas extracts a column from a **DataFrame** as a **Series**.
# - The **Series** is a view, so changes to the **Series** *will* affect the **DataFrame**.
# - Pandas will display a warning if you mutate the **Series**. Use the `copy` method to create a duplicate.

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.Team   # no space in name
# nba.team   # error
# Out:
# 0           Atlanta Hawks
# 1           Atlanta Hawks
# 2           Atlanta Hawks
# 3           Atlanta Hawks
# 4           Atlanta Hawks
#               ...
# 587    Washington Wizards
# 588    Washington Wizards
# 589    Washington Wizards
# 590    Washington Wizards
# 591                   NaN
# Name: Team, Length: 592, dtype: object

# %%
nba["Salary"]  # space in name
# Out:
# 0       4556983.0
# 1      18700000.0
# 2       4094244.0
# 3      20616000.0
# 4       2581522.0
#           ...
# 587     1719864.0
# 588    10250000.0
# 589           NaN
# 590     8195122.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64

# %%
#names = nba["Name"]
names = nba["Name"].copy()
names
# Out:
# 0             Saddiq Bey
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 587         Ryan Rollins
# 588        Landry Shamet
# 589     Tristan Vukcevic
# 590         Delon Wright
# 591                  NaN
# Name: Name, Length: 592, dtype: object

# %%
names.iloc[0]
# Out:
# 'Saddiq Bey'

# %%
names.iloc[0] = "Whatever"

# %%
names
# Out:
# 0               Whatever
# 1      Bogdan Bogdanovic
# 2            Kobe Bufkin
# 3           Clint Capela
# 4         Bruno Fernando
#              ...
# 587         Ryan Rollins
# 588        Landry Shamet
# 589     Tristan Vukcevic
# 590         Delon Wright
# 591                  NaN
# Name: Name, Length: 592, dtype: object

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %% [markdown]
# ## Select Multiple Columns from a DataFrame
# - Use square brackets with a list of names to extract multiple **DataFrame** columns.
# - Pandas stores the result in a new **DataFrame** (a copy).

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba[["Name", "Team"]]
# Out:
#                   Name                Team
# 0           Saddiq Bey       Atlanta Hawks
# 1    Bogdan Bogdanovic       Atlanta Hawks
# 2          Kobe Bufkin       Atlanta Hawks
# 3         Clint Capela       Atlanta Hawks
# 4       Bruno Fernando       Atlanta Hawks
# ..                 ...                 ...
# 587       Ryan Rollins  Washington Wizards
# 588      Landry Shamet  Washington Wizards
# 589   Tristan Vukcevic  Washington Wizards
# 590       Delon Wright  Washington Wizards
# 591                NaN                 NaN
#
# [592 rows x 2 columns]

# %%
nba[["Team", "Name"]]
# Out:
#                    Team               Name
# 0         Atlanta Hawks         Saddiq Bey
# 1         Atlanta Hawks  Bogdan Bogdanovic
# 2         Atlanta Hawks        Kobe Bufkin
# 3         Atlanta Hawks       Clint Capela
# 4         Atlanta Hawks     Bruno Fernando
# ..                  ...                ...
# 587  Washington Wizards       Ryan Rollins
# 588  Washington Wizards      Landry Shamet
# 589  Washington Wizards   Tristan Vukcevic
# 590  Washington Wizards       Delon Wright
# 591                 NaN                NaN
#
# [592 rows x 2 columns]

# %%
nba[["Salary", "Team", "Name"]]
# Out:
#          Salary                Team               Name
# 0     4556983.0       Atlanta Hawks         Saddiq Bey
# 1    18700000.0       Atlanta Hawks  Bogdan Bogdanovic
# 2     4094244.0       Atlanta Hawks        Kobe Bufkin
# 3    20616000.0       Atlanta Hawks       Clint Capela
# 4     2581522.0       Atlanta Hawks     Bruno Fernando
# ..          ...                 ...                ...
# 587   1719864.0  Washington Wizards       Ryan Rollins
# 588  10250000.0  Washington Wizards      Landry Shamet
# 589         NaN  Washington Wizards   Tristan Vukcevic
# 590   8195122.0  Washington Wizards       Delon Wright
# 591         NaN                 NaN                NaN
#
# [592 rows x 3 columns]

# %%
columns_to_select = ["Salary", "Team", "Name"]
nba[columns_to_select]
# Out:
#          Salary                Team               Name
# 0     4556983.0       Atlanta Hawks         Saddiq Bey
# 1    18700000.0       Atlanta Hawks  Bogdan Bogdanovic
# 2     4094244.0       Atlanta Hawks        Kobe Bufkin
# 3    20616000.0       Atlanta Hawks       Clint Capela
# 4     2581522.0       Atlanta Hawks     Bruno Fernando
# ..          ...                 ...                ...
# 587   1719864.0  Washington Wizards       Ryan Rollins
# 588  10250000.0  Washington Wizards      Landry Shamet
# 589         NaN  Washington Wizards   Tristan Vukcevic
# 590   8195122.0  Washington Wizards       Delon Wright
# 591         NaN                 NaN                NaN
#
# [592 rows x 3 columns]

# %% [markdown]
# ## Add New Column to DataFrame
# - Use square bracket extraction syntax with an equal sign to add a new **Series** to a **DataFrame**.
# - The `insert` method allows us to insert an element at a specific column index.
# - On the right-hand side, we can reference an existing **DataFrame** column and perform a broadcasting operation on it to create the new **Series**.

# %%
nba["Sport"] = "Basketball"

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary       Sport
# 0   4556983.0  Basketball
# 1  18700000.0  Basketball
# 2   4094244.0  Basketball
# 3  20616000.0  Basketball
# 4   2581522.0  Basketball

# %%
nba.insert(loc=3, column="Sports", value="Basketball Test")

# %%
nba.head()
# Out:
#                 Name           Team Position           Sports Height  Weight  \
# 0         Saddiq Bey  Atlanta Hawks        F  Basketball Test    6-7   215.0
# 1  Bogdan Bogdanovic  Atlanta Hawks        G  Basketball Test    6-5   225.0
# 2        Kobe Bufkin  Atlanta Hawks        G  Basketball Test    6-5   195.0
# 3       Clint Capela  Atlanta Hawks        C  Basketball Test   6-10   256.0
# 4     Bruno Fernando  Atlanta Hawks      F-C  Basketball Test   6-10   240.0
#
#        College      Salary       Sport
# 0    Villanova   4556983.0  Basketball
# 1   Fenerbahce  18700000.0  Basketball
# 2     Michigan   4094244.0  Basketball
# 3  Elan Chalon  20616000.0  Basketball
# 4     Maryland   2581522.0  Basketball

# %%
nba["Salary"] * 2
# Out:
# 0       9113966.0
# 1      37400000.0
# 2       8188488.0
# 3      41232000.0
# 4       5163044.0
#           ...
# 587     3439728.0
# 588    20500000.0
# 589           NaN
# 590    16390244.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64

# %%
nba.head()
# Out:
#                 Name           Team Position           Sports Height  Weight  \
# 0         Saddiq Bey  Atlanta Hawks        F  Basketball Test    6-7   215.0
# 1  Bogdan Bogdanovic  Atlanta Hawks        G  Basketball Test    6-5   225.0
# 2        Kobe Bufkin  Atlanta Hawks        G  Basketball Test    6-5   195.0
# 3       Clint Capela  Atlanta Hawks        C  Basketball Test   6-10   256.0
# 4     Bruno Fernando  Atlanta Hawks      F-C  Basketball Test   6-10   240.0
#
#        College      Salary       Sport
# 0    Villanova   4556983.0  Basketball
# 1   Fenerbahce  18700000.0  Basketball
# 2     Michigan   4094244.0  Basketball
# 3  Elan Chalon  20616000.0  Basketball
# 4     Maryland   2581522.0  Basketball

# %%
nba["Salary"].mul(2)
# Out:
# 0       9113966.0
# 1      37400000.0
# 2       8188488.0
# 3      41232000.0
# 4       5163044.0
#           ...
# 587     3439728.0
# 588    20500000.0
# 589           NaN
# 590    16390244.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64

# %%
nba["Salary Doubled"] = nba["Salary"].mul(2)

# %%
nba.head()
# Out:
#                 Name           Team Position           Sports Height  Weight  \
# 0         Saddiq Bey  Atlanta Hawks        F  Basketball Test    6-7   215.0
# 1  Bogdan Bogdanovic  Atlanta Hawks        G  Basketball Test    6-5   225.0
# 2        Kobe Bufkin  Atlanta Hawks        G  Basketball Test    6-5   195.0
# 3       Clint Capela  Atlanta Hawks        C  Basketball Test   6-10   256.0
# 4     Bruno Fernando  Atlanta Hawks      F-C  Basketball Test   6-10   240.0
#
#        College      Salary       Sport  Salary Doubled
# 0    Villanova   4556983.0  Basketball       9113966.0
# 1   Fenerbahce  18700000.0  Basketball      37400000.0
# 2     Michigan   4094244.0  Basketball       8188488.0
# 3  Elan Chalon  20616000.0  Basketball      41232000.0
# 4     Maryland   2581522.0  Basketball       5163044.0

# %%
nba["Salary"] - 5000000
# Out:
# 0       -443017.0
# 1      13700000.0
# 2       -905756.0
# 3      15616000.0
# 4      -2418478.0
#           ...
# 587    -3280136.0
# 588     5250000.0
# 589           NaN
# 590     3195122.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64

# %%
nba["Salary"].sub(5000000)
# Out:
# 0       -443017.0
# 1      13700000.0
# 2       -905756.0
# 3      15616000.0
# 4      -2418478.0
#           ...
# 587    -3280136.0
# 588     5250000.0
# 589           NaN
# 590     3195122.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64

# %%
nba["New Salary"] = nba["Salary"].sub(5000000)

# %%
nba.head()
# Out:
#                 Name           Team Position           Sports Height  Weight  \
# 0         Saddiq Bey  Atlanta Hawks        F  Basketball Test    6-7   215.0
# 1  Bogdan Bogdanovic  Atlanta Hawks        G  Basketball Test    6-5   225.0
# 2        Kobe Bufkin  Atlanta Hawks        G  Basketball Test    6-5   195.0
# 3       Clint Capela  Atlanta Hawks        C  Basketball Test   6-10   256.0
# 4     Bruno Fernando  Atlanta Hawks      F-C  Basketball Test   6-10   240.0
#
#        College      Salary       Sport  Salary Doubled  New Salary
# 0    Villanova   4556983.0  Basketball       9113966.0   -443017.0
# 1   Fenerbahce  18700000.0  Basketball      37400000.0  13700000.0
# 2     Michigan   4094244.0  Basketball       8188488.0   -905756.0
# 3  Elan Chalon  20616000.0  Basketball      41232000.0  15616000.0
# 4     Maryland   2581522.0  Basketball       5163044.0  -2418478.0

# %%
nba["test"] = ""

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary test
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba = pd.read_csv("nba.csv")
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %% [markdown]
# ## A Review of the value_counts Method
# - The `value_counts` method counts the number of times that each unique value occurs in a **Series**.

# %%
nba["Position"].value_counts()
# Out:
# Position
# G      229
# F      187
# C       47
# G-F     46
# F-C     37
# C-F     23
# F-G     15
# Name: count, dtype: int64

# %%
nba["Position"].value_counts(normalize=True)
# Out:
# Position
# G      0.392123
# F      0.320205
# C      0.080479
# G-F    0.078767
# F-C    0.063356
# C-F    0.039384
# F-G    0.025685
# Name: proportion, dtype: float64

# %% [markdown]
# ## Drop Rows with Missing Values
# - Pandas uses a `NaN` designation for cells that have a missing value.
# - The `dropna` method deletes rows with missing values. Its default behavior is to remove a row if it has *any* missing values.
# - Pass the `how` parameter an argument of "all" to delete rows where all the values are `NaN`.
# - The `subset` parameters customizes/limits the columns that pandas will use to drop rows with missing values.

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.dropna()   #  deltete all row which have any NaN value
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 585         Oregon    559782.0
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 590           Utah   8195122.0
#
# [475 rows x 7 columns]

# %%
nba = pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
 nba.dropna(how="any")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 585         Oregon    559782.0
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 590           Utah   8195122.0
#
# [475 rows x 7 columns]

# %%
nba = pd.read_csv("nba.csv")
nba.dropna(how="all")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba.dropna(subset=["Salary"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 585         Oregon    559782.0
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 590           Utah   8195122.0
#
# [488 rows x 7 columns]

# %%
nba.dropna(subset=["College"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
#
# [578 rows x 7 columns]

# %%
nba.dropna(subset=["College", "Salary"])
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 585     Eugene Omoruyi  Washington Wizards        F    6-6   235.0
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 585         Oregon    559782.0
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 590           Utah   8195122.0
#
# [476 rows x 7 columns]

# %%
nba.dropna(subset=["College", "Salary"] , how="all")
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
#
# [590 rows x 7 columns]

# %%
nba.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 587    0
# 588    0
# 589    1
# 590    0
# 591    7
# Length: 592, dtype: int64

# %%
nba = pd.read_csv("nba.csv")
nba.dropna(thresh=2)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %% [markdown]
# ## Fill in Missing Values with the fillna Method
# - The `fillna` method replaces missing `NaN` values with its argument.
# - The `fillna` method is available on both **DataFrames** and **Series**.
# - An extracted **Series** is a view on the original **DataFrame**, but the `fillna` method returns a copy.

# %%
nba = pd.read_csv("nba.csv").dropna(how="all")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba.fillna(0)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         0.0
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba["Salary"].count()
# Out:
# np.int64(488)

# %%
nba["Salary"] = nba["Salary"].fillna(0)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         0.0
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba["Salary"].count()
# Out:
# np.int64(591)

# %%
nba["College"].count()
# Out:
# np.int64(578)

# %%
nba["College"] = nba["College"].fillna(value="Unknown")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         0.0
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba["College"].count()
# Out:
# np.int64(591)

# %% [markdown]
# ## The astype Method I
# - The `astype` method converts a **Series's** values to a specified type.
# - Pass in the specified type as either a string or the core Python data type.
# - Pandas cannot convert `NaN` values to numeric types, so we need to eliminate/replace them before we perform the conversion.
# - The `dtypes` attribute returns a **Series** with the **DataFrame's** columns and their types.
# - The `category` type is ideal for columns with a limited number of unique values.
# - The `nunique` method will return a **Series** with the number of unique values in each column.
# - With categories, pandas does not create a separate value in memory for each "cell". Rather, the cells point to a single copy for each unique value.

# %%
nba = pd.read_csv("nba.csv").dropna(how="all")
nba["Salary"] = nba["Salary"].fillna(0)
nba["Weight"] = nba["Weight"].fillna(0)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         0.0
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   591 non-null    object
#  6   Salary    591 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 36.9+ KB

# %%
nba["Salary"].astype("int")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 586       Michigan  27955357.0
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         0.0
# 590           Utah   8195122.0
#
# [591 rows x 7 columns]

# %%
nba["Salary"].astype(int)
# Out:
# 0       4556983
# 1      18700000
# 2       4094244
# 3      20616000
# 4       2581522
#          ...
# 586    27955357
# 587     1719864
# 588    10250000
# 589           0
# 590     8195122
# Name: Salary, Length: 591, dtype: int64

# %%
nba["Salary"] = nba["Salary"].astype(int)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# 4         Maryland   2581522
# ..             ...       ...
# 586       Michigan  27955357
# 587         Toledo   1719864
# 588  Wichita State  10250000
# 589    Real Madrid         0
# 590           Utah   8195122
#
# [591 rows x 7 columns]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   591 non-null    object
#  6   Salary    591 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 36.9+ KB

# %%
df = pd.DataFrame( {
    'int' : [ 1,2,3,4],
    'float' : [1.0,2.0,3.0,4.0]
})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   int     4 non-null      int64
#  1   float   4 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 196.0 bytes

# %%
df.memory_usage()
# Out:
# Index    132
# int       32
# float     32
# dtype: int64

# %%
nba["Team"].nunique()
# Out:
# 30

# %%
nba.nunique()
# Out:
# Name        591
# Team         30
# Position      7
# Height       20
# Weight       94
# College     182
# Salary      299
# dtype: int64

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   591 non-null    object
#  6   Salary    591 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 36.9+ KB

# %%
nba["Position"] = nba["Position"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    category
#  2   Position  584 non-null    category
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   591 non-null    object
#  6   Salary    591 non-null    int64
# dtypes: category(2), float64(1), int64(1), object(3)
# memory usage: 30.5+ KB

# %%
nba["Team"] = nba["Team"].astype("category")

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 591 entries, 0 to 590
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    category
#  2   Position  584 non-null    category
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   591 non-null    object
#  6   Salary    591 non-null    int64
# dtypes: category(2), float64(1), int64(1), object(3)
# memory usage: 30.5+ KB

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# 4         Maryland   2581522
# ..             ...       ...
# 586       Michigan  27955357
# 587         Toledo   1719864
# 588  Wichita State  10250000
# 589    Real Madrid         0
# 590           Utah   8195122
#
# [591 rows x 7 columns]

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method I
# - The `sort_values` method sorts a **DataFrame** by the values in one or more columns. The default sort is an ascending one (alphabetical for strings).
# - The first parameter (`by`) expects the column(s) to sort by.
# - If sorting by a single column, pass a string with its name.
# - The `ascending` parameter customizes the sort order.
# - The `na_position` parameter customizes where pandas places `NaN` values.

# %%
nba.sort_values("Name")
# Out:
#                 Name                  Team Position Height  Weight  \
# 122      A.J. Lawson      Dallas Mavericks        G    6-6   179.0
# 324         AJ Green       Milwaukee Bucks        G    6-5   190.0
# 6         AJ Griffin         Atlanta Hawks        F    6-6   220.0
# 141     Aaron Gordon        Denver Nuggets        F    6-8   235.0
# 198    Aaron Holiday       Houston Rockets        G    6-0   185.0
# ..               ...                   ...      ...    ...     ...
# 515     Zach Collins     San Antonio Spurs      F-C   6-11   250.0
# 83       Zach LaVine         Chicago Bulls        G    6-5   200.0
# 149       Zeke Nnaji        Denver Nuggets      F-C    6-9   240.0
# 291  Ziaire Williams     Memphis Grizzlies        F    6-9   185.0
# 370  Zion Williamson  New Orleans Pelicans        F    6-6   284.0
#
#             College    Salary
# 122  South Carolina         0
# 324   Northern Iowa   1901769
# 6              Duke   3712920
# 141         Arizona  22266182
# 198            UCLA   2346614
# ..              ...       ...
# 515         Gonzaga   7700000
# 83             UCLA  40064220
# 149         Arizona   4306281
# 291        Stanford   4810200
# 370            Duke  34005250
#
# [591 rows x 7 columns]

# %%
nba["Team"].sort_values()
# Out:
# 0           Atlanta Hawks
# 17          Atlanta Hawks
# 16          Atlanta Hawks
# 15          Atlanta Hawks
# 14          Atlanta Hawks
#               ...
# 571    Washington Wizards
# 570    Washington Wizards
# 589    Washington Wizards
# 579    Washington Wizards
# 590    Washington Wizards
# Name: Team, Length: 591, dtype: category
# Categories (30, object): ['Atlanta Hawks', 'Boston Celtics', 'Brooklyn Nets', 'Charlotte Hornets', ..., 'San Antonio Spurs', 'Toronto Raptors', 'Utah Jazz', 'Washington Wizards']

# %%
nba.sort_values(by="Name")
# Out:
#                 Name                  Team Position Height  Weight  \
# 122      A.J. Lawson      Dallas Mavericks        G    6-6   179.0
# 324         AJ Green       Milwaukee Bucks        G    6-5   190.0
# 6         AJ Griffin         Atlanta Hawks        F    6-6   220.0
# 141     Aaron Gordon        Denver Nuggets        F    6-8   235.0
# 198    Aaron Holiday       Houston Rockets        G    6-0   185.0
# ..               ...                   ...      ...    ...     ...
# 515     Zach Collins     San Antonio Spurs      F-C   6-11   250.0
# 83       Zach LaVine         Chicago Bulls        G    6-5   200.0
# 149       Zeke Nnaji        Denver Nuggets      F-C    6-9   240.0
# 291  Ziaire Williams     Memphis Grizzlies        F    6-9   185.0
# 370  Zion Williamson  New Orleans Pelicans        F    6-6   284.0
#
#             College    Salary
# 122  South Carolina         0
# 324   Northern Iowa   1901769
# 6              Duke   3712920
# 141         Arizona  22266182
# 198            UCLA   2346614
# ..              ...       ...
# 515         Gonzaga   7700000
# 83             UCLA  40064220
# 149         Arizona   4306281
# 291        Stanford   4810200
# 370            Duke  34005250
#
# [591 rows x 7 columns]

# %%
nba.sort_values(by="Name", ascending=True)
# Out:
#                 Name                  Team Position Height  Weight  \
# 122      A.J. Lawson      Dallas Mavericks        G    6-6   179.0
# 324         AJ Green       Milwaukee Bucks        G    6-5   190.0
# 6         AJ Griffin         Atlanta Hawks        F    6-6   220.0
# 141     Aaron Gordon        Denver Nuggets        F    6-8   235.0
# 198    Aaron Holiday       Houston Rockets        G    6-0   185.0
# ..               ...                   ...      ...    ...     ...
# 515     Zach Collins     San Antonio Spurs      F-C   6-11   250.0
# 83       Zach LaVine         Chicago Bulls        G    6-5   200.0
# 149       Zeke Nnaji        Denver Nuggets      F-C    6-9   240.0
# 291  Ziaire Williams     Memphis Grizzlies        F    6-9   185.0
# 370  Zion Williamson  New Orleans Pelicans        F    6-6   284.0
#
#             College    Salary
# 122  South Carolina         0
# 324   Northern Iowa   1901769
# 6              Duke   3712920
# 141         Arizona  22266182
# 198            UCLA   2346614
# ..              ...       ...
# 515         Gonzaga   7700000
# 83             UCLA  40064220
# 149         Arizona   4306281
# 291        Stanford   4810200
# 370            Duke  34005250
#
# [591 rows x 7 columns]

# %%
nba.sort_values(by="Name", ascending=False)
# Out:
#                 Name                  Team Position Height  Weight  \
# 370  Zion Williamson  New Orleans Pelicans        F    6-6   284.0
# 291  Ziaire Williams     Memphis Grizzlies        F    6-9   185.0
# 149       Zeke Nnaji        Denver Nuggets      F-C    6-9   240.0
# 83       Zach LaVine         Chicago Bulls        G    6-5   200.0
# 515     Zach Collins     San Antonio Spurs      F-C   6-11   250.0
# ..               ...                   ...      ...    ...     ...
# 198    Aaron Holiday       Houston Rockets        G    6-0   185.0
# 141     Aaron Gordon        Denver Nuggets        F    6-8   235.0
# 6         AJ Griffin         Atlanta Hawks        F    6-6   220.0
# 324         AJ Green       Milwaukee Bucks        G    6-5   190.0
# 122      A.J. Lawson      Dallas Mavericks        G    6-6   179.0
#
#             College    Salary
# 370            Duke  34005250
# 291        Stanford   4810200
# 149         Arizona   4306281
# 83             UCLA  40064220
# 515         Gonzaga   7700000
# ..              ...       ...
# 198            UCLA   2346614
# 141         Arizona  22266182
# 6              Duke   3712920
# 324   Northern Iowa   1901769
# 122  South Carolina         0
#
# [591 rows x 7 columns]

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# 4         Maryland   2581522
# ..             ...       ...
# 586       Michigan  27955357
# 587         Toledo   1719864
# 588  Wichita State  10250000
# 589    Real Madrid         0
# 590           Utah   8195122
#
# [591 rows x 7 columns]

# %% [markdown]
# ## Sort a DataFrame with the sort_values Method I
# - The `sort_values` method sorts a **DataFrame** by the values in one or more columns. The default sort is an ascending one (alphabetical for strings).
# - The first parameter (`by`) expects the column(s) to sort by.
# - If sorting by a single column, pass a string with its name.
# - The `ascending` parameter customizes the sort order.
# - The `na_position` parameter customizes where pandas places `NaN` values.
#
# ## Sort a DataFrame with the sort_values Method II
# - To sort by multiple columns, pass the `by` parameter a list of column names. Pandas will sort in the specified column order (first to last).
# - Pass the `ascending` parameter a Boolean to sort all columns in a consistent order (all ascending or all descending).
# - Pass `ascending` a list to customize the sort order *per* column. The `ascending` list length must match the `by` list.

# %%
nba= pd.read_csv("nba.csv")
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.sort_values("Salary")
# Out:
#                  Name                 Team Position Height  Weight  \
# 5       Trent Forrest        Atlanta Hawks        G    6-4   210.0
# 585    Eugene Omoruyi   Washington Wizards        F    6-6   235.0
# 540   Markquis Nowell      Toronto Raptors        G    5-8   160.0
# 523   Sir'Jabari Rice    San Antonio Spurs        G    6-4   180.0
# 103     Isaiah Mobley  Cleveland Cavaliers        F    6-8   238.0
# ..                ...                  ...      ...    ...     ...
# 547    Gary Trent Jr.      Toronto Raptors      G-F    6-5   209.0
# 578        Taj Gibson   Washington Wizards        F    6-9   232.0
# 584     Kendrick Nunn   Washington Wizards        G    6-3   190.0
# 589  Tristan Vukcevic   Washington Wizards        F   6-10   220.0
# 591               NaN                  NaN      NaN    NaN     NaN
#
#                  College    Salary
# 5          Florida State  508891.0
# 585               Oregon  559782.0
# 540         Kansas State  559782.0
# 523                Texas  559782.0
# 103  Southern California  559782.0
# ..                   ...       ...
# 547                 Duke       NaN
# 578  Southern California       NaN
# 584              Oakland       NaN
# 589          Real Madrid       NaN
# 591                  NaN       NaN
#
# [592 rows x 7 columns]

# %%
nba.sort_values("Salary", ascending=False)
# Out:
#                  Name                   Team Position Height  Weight  \
# 175     Stephen Curry  Golden State Warriors        G    6-2   185.0
# 461      Kevin Durant           Phoenix Suns        F   6-10   240.0
# 261      LeBron James     Los Angeles Lakers        F    6-9   250.0
# 436       Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# 145      Nikola Jokic         Denver Nuggets        C   6-11   284.0
# ..                ...                    ...      ...    ...     ...
# 547    Gary Trent Jr.        Toronto Raptors      G-F    6-5   209.0
# 578        Taj Gibson     Washington Wizards        F    6-9   232.0
# 584     Kendrick Nunn     Washington Wizards        G    6-3   190.0
# 589  Tristan Vukcevic     Washington Wizards        F   6-10   220.0
# 591               NaN                    NaN      NaN    NaN     NaN
#
#                           College      Salary
# 175                      Davidson  51915615.0
# 461                         Texas  47649433.0
# 261  St. Vincent-St. Mary HS (OH)  47607350.0
# 436                        Kansas  47607350.0
# 145                   Mega Basket  47607350.0
# ..                            ...         ...
# 547                          Duke         NaN
# 578           Southern California         NaN
# 584                       Oakland         NaN
# 589                   Real Madrid         NaN
# 591                           NaN         NaN
#
# [592 rows x 7 columns]

# %%
nba.sort_values("Salary", na_position="last")
# Out:
#                  Name                 Team Position Height  Weight  \
# 5       Trent Forrest        Atlanta Hawks        G    6-4   210.0
# 585    Eugene Omoruyi   Washington Wizards        F    6-6   235.0
# 540   Markquis Nowell      Toronto Raptors        G    5-8   160.0
# 523   Sir'Jabari Rice    San Antonio Spurs        G    6-4   180.0
# 103     Isaiah Mobley  Cleveland Cavaliers        F    6-8   238.0
# ..                ...                  ...      ...    ...     ...
# 547    Gary Trent Jr.      Toronto Raptors      G-F    6-5   209.0
# 578        Taj Gibson   Washington Wizards        F    6-9   232.0
# 584     Kendrick Nunn   Washington Wizards        G    6-3   190.0
# 589  Tristan Vukcevic   Washington Wizards        F   6-10   220.0
# 591               NaN                  NaN      NaN    NaN     NaN
#
#                  College    Salary
# 5          Florida State  508891.0
# 585               Oregon  559782.0
# 540         Kansas State  559782.0
# 523                Texas  559782.0
# 103  Southern California  559782.0
# ..                   ...       ...
# 547                 Duke       NaN
# 578  Southern California       NaN
# 584              Oakland       NaN
# 589          Real Madrid       NaN
# 591                  NaN       NaN
#
# [592 rows x 7 columns]

# %%
nba.sort_values("Salary", na_position="first")
# Out:
#                     Name                   Team Position Height  Weight  \
# 23         Blake Griffin         Boston Celtics        F    6-9   250.0
# 26     Mfiondu Kabengele         Boston Celtics        C   6-10   250.0
# 28        Svi Mykhailiuk         Boston Celtics      G-F    6-7   205.0
# 35   Robert Williams III         Boston Celtics      C-F    6-9   237.0
# 39           Nic Claxton          Brooklyn Nets        C   6-11   215.0
# ..                   ...                    ...      ...    ...     ...
# 436          Joel Embiid     Philadelphia 76ers      C-F    7-0   280.0
# 261         LeBron James     Los Angeles Lakers        F    6-9   250.0
# 145         Nikola Jokic         Denver Nuggets        C   6-11   284.0
# 461         Kevin Durant           Phoenix Suns        F   6-10   240.0
# 175        Stephen Curry  Golden State Warriors        G    6-2   185.0
#
#                           College      Salary
# 23                       Oklahoma         NaN
# 26                  Florida State         NaN
# 28                         Kansas         NaN
# 35                      Texas A&M         NaN
# 39                        Georgia         NaN
# ..                            ...         ...
# 436                        Kansas  47607350.0
# 261  St. Vincent-St. Mary HS (OH)  47607350.0
# 145                   Mega Basket  47607350.0
# 461                         Texas  47649433.0
# 175                      Davidson  51915615.0
#
# [592 rows x 7 columns]

# %%
nba.sort_values("Salary", na_position="first", ascending=False)
# Out:
#                     Name               Team Position Height  Weight  \
# 23         Blake Griffin     Boston Celtics        F    6-9   250.0
# 26     Mfiondu Kabengele     Boston Celtics        C   6-10   250.0
# 28        Svi Mykhailiuk     Boston Celtics      G-F    6-7   205.0
# 35   Robert Williams III     Boston Celtics      C-F    6-9   237.0
# 39           Nic Claxton      Brooklyn Nets        C   6-11   215.0
# ..                   ...                ...      ...    ...     ...
# 55           Leaky Black  Charlotte Hornets        F    6-9   209.0
# 74         Onuralp Bitim      Chicago Bulls        F    6-6   215.0
# 523      Sir'Jabari Rice  San Antonio Spurs        G    6-4   180.0
# 540      Markquis Nowell    Toronto Raptors        G    5-8   160.0
# 5          Trent Forrest      Atlanta Hawks        G    6-4   210.0
#
#             College    Salary
# 23         Oklahoma       NaN
# 26    Florida State       NaN
# 28           Kansas       NaN
# 35        Texas A&M       NaN
# 39          Georgia       NaN
# ..              ...       ...
# 55   North Carolina  559782.0
# 74              NaN  559782.0
# 523           Texas  559782.0
# 540    Kansas State  559782.0
# 5     Florida State  508891.0
#
# [592 rows x 7 columns]

# %%
nba.sort_values(["Team", "Name"])
# nba.sort_values(by=["Team", "Name"])
# nba.sort_values(by=["Team", "Name"], ascending=True)
# nba.sort_values(by=["Team", "Name"], ascending=False)
# Out:
#                   Name                Team Position Height  Weight  \
# 6           AJ Griffin       Atlanta Hawks        F    6-6   220.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 8      De'Andre Hunter       Atlanta Hawks      F-G    6-8   221.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 578         Taj Gibson  Washington Wizards        F    6-9   232.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 580         Tyus Jones  Washington Wizards        G    6-2   196.0
# 573       Xavier Cooks  Washington Wizards        F    6-8   183.0
#
#                  College    Salary
# 6                   Duke   3712920
# 1             Fenerbahce  18700000
# 4               Maryland   2581522
# 3            Elan Chalon  20616000
# 8               Virginia  20089286
# ..                   ...       ...
# 587               Toledo   1719864
# 578  Southern California         0
# 589          Real Madrid         0
# 580                 Duke  14000000
# 573             Winthrop   1719864
#
# [591 rows x 7 columns]

# %%
nba.sort_values(by=["Team", "Name"], ascending=[True, False])
# Out:
#                  Name                Team Position Height  Weight  \
# 12    Wesley Matthews       Atlanta Hawks        G    6-5   220.0
# 5       Trent Forrest       Atlanta Hawks        G    6-4   210.0
# 17         Trae Young       Atlanta Hawks        G    6-1   164.0
# 10         Seth Lundy       Atlanta Hawks        G    6-6   220.0
# 0          Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# ..                ...                 ...      ...    ...     ...
# 577  Danilo Gallinari  Washington Wizards        F   6-10   236.0
# 576    Daniel Gafford  Washington Wizards      F-C   6-10   234.0
# 581     Corey Kispert  Washington Wizards        F    6-6   224.0
# 574   Bilal Coulibaly  Washington Wizards        G    6-6   195.0
# 579      Anthony Gill  Washington Wizards        F    6-8   230.0
#
#               College    Salary
# 12          Marquette   3196448
# 5       Florida State    508891
# 17           Oklahoma  40064220
# 10         Penn State    559782
# 0           Villanova   4556983
# ..                ...       ...
# 577    Olimpia Milano   6802950
# 576          Arkansas  12402000
# 581           Gonzaga   3722040
# 574  Metropolitans 92   6614256
# 579          Virginia   1997238
#
# [591 rows x 7 columns]

# %%
nba.sort_values(["Position", "Salary"])
# Out:
#                 Name                    Team Position Height  Weight  \
# 143         Jay Huff          Denver Nuggets        C    7-1   240.0
# 252  Colin Castleton      Los Angeles Lakers        C   6-11   250.0
# 343       Luka Garza  Minnesota Timberwolves        C   6-10   243.0
# 406     Olivier Sarr   Oklahoma City Thunder        C   6-11   240.0
# 473       Ibou Badji  Portland Trail Blazers        C    7-1   240.0
# ..               ...                     ...      ...    ...     ...
# 138  Armaan Franklin          Denver Nuggets      NaN    NaN     NaN
# 299    Caleb Daniels              Miami Heat      NaN    NaN     NaN
# 541     Kevin Obanor         Toronto Raptors      NaN    6-8   235.0
# 564     Nick Ongenda               Utah Jazz      NaN    NaN     NaN
# 591              NaN                     NaN      NaN    NaN     NaN
#
#           College     Salary
# 143      Virginia   559782.0
# 252       Florida   559782.0
# 343          Iowa   559782.0
# 406      Kentucky   559782.0
# 473  FC Barcelona   559782.0
# ..            ...        ...
# 138           NaN  1119563.0
# 299           NaN  1119563.0
# 541           NaN  1119563.0
# 564           NaN  1119563.0
# 591           NaN        NaN
#
# [592 rows x 7 columns]

# %%
nba = nba.sort_values(["Position", "Salary"], ascending=[False, True])
nba
# Out:
#                 Name                    Team Position Height  Weight  \
# 392    Dylan Windler         New York Knicks      G-F    6-7   196.0
# 202   Joshua Obiesie         Houston Rockets      G-F    6-6   195.0
# 484     Rayan Rupert  Portland Trail Blazers      G-F    6-6   185.0
# 130     Joe Wieskamp        Dallas Mavericks      G-F    6-6   205.0
# 197      Nate Hinton         Houston Rockets      G-F    6-5   210.0
# ..               ...                     ...      ...    ...     ...
# 138  Armaan Franklin          Denver Nuggets      NaN    NaN     NaN
# 299    Caleb Daniels              Miami Heat      NaN    NaN     NaN
# 541     Kevin Obanor         Toronto Raptors      NaN    6-8   235.0
# 564     Nick Ongenda               Utah Jazz      NaN    NaN     NaN
# 591              NaN                     NaN      NaN    NaN     NaN
#
#                   College     Salary
# 392               Belmont   559782.0
# 202                   NaN  1119563.0
# 484  New Zealand Breakers  1119563.0
# 130                  Iowa  2019706.0
# 197               Houston  2019706.0
# ..                    ...        ...
# 138                   NaN  1119563.0
# 299                   NaN  1119563.0
# 541                   NaN  1119563.0
# 564                   NaN  1119563.0
# 591                   NaN        NaN
#
# [592 rows x 7 columns]

# %% [markdown]
# ## Sort a DataFrame by its Index
# - The `sort_index` method sorts the **DataFrame** by its index positions/labels.

# %%
nba
# Out:
#                 Name                    Team Position Height  Weight  \
# 392    Dylan Windler         New York Knicks      G-F    6-7   196.0
# 202   Joshua Obiesie         Houston Rockets      G-F    6-6   195.0
# 484     Rayan Rupert  Portland Trail Blazers      G-F    6-6   185.0
# 130     Joe Wieskamp        Dallas Mavericks      G-F    6-6   205.0
# 197      Nate Hinton         Houston Rockets      G-F    6-5   210.0
# ..               ...                     ...      ...    ...     ...
# 138  Armaan Franklin          Denver Nuggets      NaN    NaN     NaN
# 299    Caleb Daniels              Miami Heat      NaN    NaN     NaN
# 541     Kevin Obanor         Toronto Raptors      NaN    6-8   235.0
# 564     Nick Ongenda               Utah Jazz      NaN    NaN     NaN
# 591              NaN                     NaN      NaN    NaN     NaN
#
#                   College     Salary
# 392               Belmont   559782.0
# 202                   NaN  1119563.0
# 484  New Zealand Breakers  1119563.0
# 130                  Iowa  2019706.0
# 197               Houston  2019706.0
# ..                    ...        ...
# 138                   NaN  1119563.0
# 299                   NaN  1119563.0
# 541                   NaN  1119563.0
# 564                   NaN  1119563.0
# 591                   NaN        NaN
#
# [592 rows x 7 columns]

# %%
nba.sort_index()
# nba.sort_index(ascending=True)
# nba.sort_index(ascending=False)
# nba = nba.sort_index(ascending=False)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# 4         Maryland   2581522.0
# ..             ...         ...
# 587         Toledo   1719864.0
# 588  Wichita State  10250000.0
# 589    Real Madrid         NaN
# 590           Utah   8195122.0
# 591            NaN         NaN
#
# [592 rows x 7 columns]

# %% [markdown]
# ## Rank Values with the rank Method
# - The `rank` method assigns a numeric ranking to each **Series** value.
# - Pandas will assign the same rank to equal values and create a "gap" in the dataset for the ranks.

# %%
nba = pd.read_csv("nba.csv").dropna(how="all")
nba["Salary"] = nba["Salary"].fillna(0).astype(int)
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary
# 0        Villanova   4556983
# 1       Fenerbahce  18700000
# 2         Michigan   4094244
# 3      Elan Chalon  20616000
# 4         Maryland   2581522
# ..             ...       ...
# 586       Michigan  27955357
# 587         Toledo   1719864
# 588  Wichita State  10250000
# 589    Real Madrid         0
# 590           Utah   8195122
#
# [591 rows x 7 columns]

# %%
nba["Salary"].rank()
# Out:
# 0      361.0
# 1      512.0
# 2      349.0
# 3      523.0
# 4      284.0
#        ...
# 586    544.0
# 587    197.5
# 588    452.0
# 589     52.0
# 590    429.0
# Name: Salary, Length: 591, dtype: float64

# %%
nba["Salary"].rank(ascending=True)
# Out:
# 0      361.0
# 1      512.0
# 2      349.0
# 3      523.0
# 4      284.0
#        ...
# 586    544.0
# 587    197.5
# 588    452.0
# 589     52.0
# 590    429.0
# Name: Salary, Length: 591, dtype: float64

# %%
nba["Salary"].rank(ascending=False)
# Out:
# 0      231.0
# 1       80.0
# 2      243.0
# 3       69.0
# 4      308.0
#        ...
# 586     48.0
# 587    394.5
# 588    140.0
# 589    540.0
# 590    163.0
# Name: Salary, Length: 591, dtype: float64

# %%
nba["Salary"].rank(ascending=False).astype(int)
# Out:
# 0      231
# 1       80
# 2      243
# 3       69
# 4      308
#       ...
# 586     48
# 587    394
# 588    140
# 589    540
# 590    163
# Name: Salary, Length: 591, dtype: int64

# %%
nba["Salary Rank"] = nba["Salary"].rank(ascending=False).astype(int)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 586       Jordan Poole  Washington Wizards        G    6-4   194.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
#
#            College    Salary  Salary Rank
# 0        Villanova   4556983          231
# 1       Fenerbahce  18700000           80
# 2         Michigan   4094244          243
# 3      Elan Chalon  20616000           69
# 4         Maryland   2581522          308
# ..             ...       ...          ...
# 586       Michigan  27955357           48
# 587         Toledo   1719864          394
# 588  Wichita State  10250000          140
# 589    Real Madrid         0          540
# 590           Utah   8195122          163
#
# [591 rows x 8 columns]

# %%
nba.sort_values("Salary", ascending=False).head(10)
# Out:
#                       Name                    Team Position Height  Weight  \
# 175          Stephen Curry   Golden State Warriors        G    6-2   185.0
# 461           Kevin Durant            Phoenix Suns        F   6-10   240.0
# 145           Nikola Jokic          Denver Nuggets        C   6-11   284.0
# 436            Joel Embiid      Philadelphia 76ers      C-F    7-0   280.0
# 261           LeBron James      Los Angeles Lakers        F    6-9   250.0
# 456           Bradley Beal            Phoenix Suns        G    6-4   207.0
# 480         Damian Lillard  Portland Trail Blazers        G    6-2   195.0
# 316  Giannis Antetokounmpo         Milwaukee Bucks        F    7-0   243.0
# 239            Paul George    Los Angeles Clippers        F    6-8   220.0
# 241          Kawhi Leonard    Los Angeles Clippers        F    6-7   225.0
#
#                           College    Salary  Salary Rank
# 175                      Davidson  51915615            1
# 461                         Texas  47649433            2
# 145                   Mega Basket  47607350            4
# 436                        Kansas  47607350            4
# 261  St. Vincent-St. Mary HS (OH)  47607350            4
# 456                       Florida  46741590            6
# 480                   Weber State  45640084            8
# 316                 Filathlitikos  45640084            8
# 239                  Fresno State  45640084            8
# 241               San Diego State  45640084            8

# %%
nba.sort_values("Salary", ascending=False).tail(5)
# Out:
#                  Name                Team Position Height  Weight  \
# 543   Otto Porter Jr.     Toronto Raptors        F    6-8   198.0
# 544   Dennis Schroder     Toronto Raptors        G    6-1   172.0
# 584     Kendrick Nunn  Washington Wizards        G    6-3   190.0
# 547    Gary Trent Jr.     Toronto Raptors      G-F    6-5   209.0
# 589  Tristan Vukcevic  Washington Wizards        F   6-10   220.0
#
#           College  Salary  Salary Rank
# 543    Georgetown       0          540
# 544  Braunschweig       0          540
# 584       Oakland       0          540
# 547          Duke       0          540
# 589   Real Madrid       0          540

# %% [markdown]
# # Filtering Data

# %%
employees = pd.read_csv("employees.csv")

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
employees["Start Date"] = pd.to_datetime(employees["Start Date"], format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 49.1+ KB

# %%
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
import datetime as dt

# %%
employees["Gender"] == "Male"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
employees["Gender"].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
employees.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      542
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %%
employees["Gender"].value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
employees[employees["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry   Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18        01:35:00  115163   10.125
# ..         ...    ...        ...             ...     ...      ...
# 994     George   Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
on_finance_team = employees["Team"] == "Finance"
employees[on_finance_team]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14        07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28        10:47:00  114796    6.796
# ..         ...     ...        ...             ...     ...      ...
# 907  Elizabeth  Female 1998-07-27        11:12:00  137144   10.081
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management     Team
# 2                False  Finance
# 3                 True  Finance
# 7                 True  Finance
# 14                True  Finance
# 46               False  Finance
# ..                 ...      ...
# 907              False  Finance
# 954               True  Finance
# 987               True  Finance
# 992               True  Finance
# 996              False  Finance
#
# [102 rows x 8 columns]

# %%
employees[employees["Senior Management"]].head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
# 6       Ruby  Female 1987-08-17        04:20:00   65476   10.012
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 3               True          Finance
# 4               True  Client Services
# 6               True          Product

# %%
employees[employees["Salary"] > 110000]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01        01:08:00  112807   17.492
# ..         ...     ...        ...             ...     ...      ...
# 987     Gloria  Female 2014-12-08        05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25        05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# 3                 True               Finance
# 5                False                 Legal
# 9                 True  Business Development
# 12                True       Human Resources
# ..                 ...                   ...
# 987               True               Finance
# 991               True             Marketing
# 992               True               Finance
# 995              False          Distribution
# 999               True                 Sales
#
# [322 rows x 8 columns]

# %%
employees[employees["Bonus %"] < 1.5]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 58     Theresa  Female 2010-04-11        07:18:00   72670    1.481
# 77     Charles    Male 2004-09-14        08:13:00  107391    1.260
# 175     Willie    Male 1998-02-17        08:20:00  146651    1.451
# 189   Clarence    Male 1998-05-02        03:16:00   85700    1.215
# 217    Douglas    Male 1999-09-03        04:00:00   83341    1.015
# 273   Nicholas    Male 1994-04-12        08:21:00   74669    1.113
# 279       Ruby  Female 2000-11-08        07:35:00  105946    1.139
# 365     Gloria     NaN 1983-07-19        01:57:00  140885    1.113
# 445      Chris    Male 2006-12-12        01:57:00   71642    1.496
# 481        NaN  Female 2013-04-27        06:40:00   93847    1.085
# 527      Helen     NaN 1993-12-02        01:42:00   45724    1.022
# 570      Kelly  Female 1996-08-16        03:09:00   41427    1.431
# 578     Amanda  Female 1982-03-17        11:46:00  107111    1.438
# 579     Harold    Male 2010-10-18        08:45:00   65673    1.187
# 617      Kathy  Female 2001-01-14        05:11:00   45682    1.451
# 618      Peter    Male 1992-11-24        05:43:00   69297    1.268
# 638    Frances  Female 1996-11-12        06:08:00  112467    1.433
# 652     Willie    Male 2009-12-05        05:39:00  141932    1.017
# 708      Steve    Male 2002-01-11        09:17:00   51821    1.197
# 732      Henry    Male 1986-05-12        02:04:00   59943    1.432
# 734        NaN  Female 1994-12-18        08:42:00  138807    1.400
# 746     Gloria  Female 2004-08-19        10:31:00   46602    1.027
# 912        Joe    Male 1998-12-08        10:28:00  126120    1.020
# 929    Theresa  Female 2001-04-27        09:17:00   75661    1.079
# 954        Joe    Male 1980-01-19        04:06:00  119667    1.148
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
#
#      Senior Management                  Team
# 4                 True       Client Services
# 15               False               Product
# 58                True           Engineering
# 77                True             Marketing
# 175               True           Engineering
# 189              False                 Sales
# 217               True       Client Services
# 273               True               Product
# 279              False  Business Development
# 365              False       Human Resources
# 445              False                   NaN
# 481               True  Business Development
# 527              False               Product
# 570              False               Product
# 578               True               Product
# 579               True                 Legal
# 617               True             Marketing
# 618              False               Finance
# 638              False  Business Development
# 652               True           Engineering
# 708               True                 Legal
# 732              False               Finance
# 734               True       Human Resources
# 746               True  Business Development
# 912              False                   NaN
# 929               True                 Legal
# 954               True               Finance
# 997              False               Product

# %%
employees[employees["Start Date"] < "1985-01-01"]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23        10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27        06:30:00  124008   13.464
# 37       Linda  Female 1981-10-19        08:49:00   57427    9.557
# ..         ...     ...        ...             ...     ...      ...
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
# 983       John    Male 1982-12-23        10:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 986      Donna  Female 1982-11-26        07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %% [markdown]
# ## Filter with More than One Conditio

# %%
# female employees who work in Marketing who earn over $100k a year

is_female = employees["Gender"] == "Female"
is_in_marketing = employees["Team"] == "Marketing"
salary_over_100k = employees["Salary"] > 100000
is_female & is_in_marketing & salary_over_100k
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
employees[is_female & is_in_marketing & salary_over_100k]
# Out:
#      First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 98         Tina  Female 2016-06-16        07:47:00  100705   16.961
# 140     Shirley  Female 1981-02-28        01:23:00  113850    1.854
# 158       Norma  Female 1999-02-28        08:45:00  114412    8.756
# 305    Margaret  Female 1993-02-06        01:05:00  125220    3.733
# 319  Jacqueline  Female 1981-11-25        03:01:00  145988   18.243
# 379         NaN  Female 2002-09-18        12:39:00  118906    4.537
# 468      Janice  Female 1997-06-28        01:48:00  136032   10.696
# 490      Judith  Female 2007-11-23        01:22:00  117055    7.461
# 531    Virginia  Female 2010-05-02        09:10:00  123649   10.154
# 585     Shirley  Female 1988-04-16        11:09:00  132156    2.754
# 627        Anne  Female 1984-11-21        12:30:00  128305   16.636
# 656        Lisa  Female 1982-02-09        06:44:00  113592   17.108
# 675       Diane  Female 2009-10-30        06:56:00  130577   12.791
# 676       Annie  Female 1992-06-06        10:04:00  138925    9.801
# 811      Judith  Female 1989-09-03        11:16:00  134048    6.818
# 813      Evelyn  Female 2002-02-10        04:44:00  123621   19.767
# 881        Ruby  Female 1980-01-28        11:08:00  142868    6.318
# 991        Rose  Female 2002-08-25        05:12:00  134505   11.051
#
#      Senior Management       Team
# 98                True  Marketing
# 140              False  Marketing
# 158               True  Marketing
# 305              False  Marketing
# 319              False  Marketing
# 379               True  Marketing
# 468               True  Marketing
# 490              False  Marketing
# 531               True  Marketing
# 585              False  Marketing
# 627              False  Marketing
# 656               True  Marketing
# 675              False  Marketing
# 676               True  Marketing
# 811               True  Marketing
# 813               True  Marketing
# 881              False  Marketing
# 991               True  Marketing

# %%
# Employees who are either senior management OR started before January 1st, 1990

is_senior_management = employees["Senior Management"]
started_in_80s = employees["Start Date"] < "1990-01-01"

employees[is_senior_management | started_in_80s]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %%
# First Name is Robert who work in Client Services OR Start Date after 2016-06-01

# %%
is_robert = employees["First Name"] == "Robert"
is_in_client_services = employees["Team"] == "Client Services"
start_date_after_june_2016 = employees["Start Date"] > "2016-06-01"

# %%
employees[(is_robert & is_in_client_services) | start_date_after_june_2016]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16        07:47:00  100705   16.961
# 387     Robert    Male 1994-10-29        04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15        12:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %%
# Legal Team or Sales Team or Product Team

legal_team = employees["Team"] == "Legal"
sales_team = employees["Team"] == "Sales"
product_team = employees["Team"] == "Product"

employees[legal_team | sales_team | product_team]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 11       Julie  Female 1997-10-26        03:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        11:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        05:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
target_teams = employees["Team"].isin(["Legal", "Sales", "Product"])
employees[target_teams]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 11       Julie  Female 1997-10-26        03:19:00  102508   12.637
# 13        Gary    Male 2008-01-27        11:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05        06:09:00   59414    1.256
# ..         ...     ...        ...             ...     ...      ...
# 981      James    Male 1993-01-15        05:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10        08:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %%
employees = pd.read_csv("employees.csv", parse_dates=["Start Date"], date_format="%m/%d/%Y")
employees["Last Login Time"] = pd.to_datetime(employees["Last Login Time"], format="%H:%M %p").dt.time
employees["Senior Management"] = employees["Senior Management"].astype(bool)
employees["Gender"] = employees["Gender"].astype("category")
employees.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4      Larry    Male 1998-01-24        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees["Team"].isnull().sum()
# Out:
# np.int64(43)

# %%
employees[employees["Team"].isnull()]
# Out:
#       First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12        09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14        04:19:00  125792    5.042
# 32           NaN    Male 1998-08-21        02:27:00  122340    6.417
# 91         James     NaN 2005-01-26        11:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22        10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03        01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17        08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24        03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14        06:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31        05:40:00  112117    6.338
# 367       Edward    Male 1989-08-04        06:06:00   66067   10.957
# 382          NaN  Female 1996-04-18        03:57:00  107024   12.182
# 434        Joyce  Female 1995-02-07        07:38:00   50701   14.227
# 438        Jason    Male 1998-11-20        02:54:00   69244    6.220
# 445        Chris    Male 2006-12-12        01:57:00   71642    1.496
# 479      Richard    Male 1997-07-04        11:47:00   47647   18.787
# 512        Wanda  Female 1993-04-06        03:11:00   78883   19.695
# 513        Jimmy    Male 2013-11-19        07:29:00   63549   19.624
# 520        Peter    Male 2003-02-22        09:09:00   56580    8.411
# 567          NaN  Female 1980-04-01        08:04:00   48141   12.605
# 573     Kimberly  Female 1981-12-30        04:51:00   81800    5.435
# 580        Harry    Male 1985-01-27        08:18:00   65482   18.089
# 626          NaN  Female 1997-04-13        08:03:00  131755    2.930
# 634         Carl    Male 1987-03-30        05:59:00   75598   19.289
# 635        Randy    Male 2000-09-27        03:04:00   89831   13.047
# 647       Donald    Male 1988-04-06        10:00:00  122920    5.320
# 669       Joseph     NaN 1982-03-28        01:05:00   86564   11.879
# 684        Alice  Female 2016-01-21        05:07:00  117787   10.485
# 706         Todd    Male 1993-07-04        06:53:00  128175   18.473
# 726       Daniel    Male 2016-02-29        04:04:00   77287   13.000
# 753      Antonio    Male 1999-06-06        10:54:00   41928    5.478
# 774          NaN  Female 2000-06-18        07:36:00  106428   10.867
# 781     Lawrence    Male 1995-07-03        10:55:00   46378    9.127
# 794       Nicole  Female 2004-03-01        05:17:00   44021   10.286
# 826          NaN     NaN 1988-08-01        01:35:00   87103    5.665
# 850      Charles    Male 1997-09-03        10:04:00  148291    6.002
# 851        Bobby    Male 1996-08-19        01:16:00  147842   16.158
# 853      Mildred  Female 2007-04-06        10:06:00  139284   11.390
# 855      Phillip     NaN 2003-10-20        11:09:00   89700    2.277
# 864         Ryan    Male 2012-11-16        01:47:00   57292    6.010
# 912          Joe    Male 1998-12-08        10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14        05:19:00  143638    9.662
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
employees[employees["Team"].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [957 rows x 8 columns]

# %%
employees[employees["First Name"].isnull() & employees["Team"].notnull()]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 7          NaN  Female 2015-07-20        10:43:00   45906   11.598
# 25         NaN    Male 2012-10-08        01:12:00   37076   18.576
# 39         NaN    Male 2016-01-29        02:33:00  122173    7.797
# 51         NaN     NaN 2011-12-17        08:29:00   41126   14.009
# 62         NaN  Female 2007-06-12        05:25:00   58112   19.414
# 116        NaN    Male 1991-06-22        08:58:00   76189   18.988
# 149        NaN  Female 2014-08-17        02:00:00   86230    8.578
# 157        NaN  Female 2005-07-27        08:32:00   79536   14.443
# 165        NaN  Female 2014-03-23        01:28:00   59148    9.061
# 166        NaN  Female 1991-07-09        06:52:00   42341    7.014
# 174        NaN     NaN 2007-09-18        06:59:00   40297    6.185
# 186        NaN  Female 2005-02-23        09:50:00  149654    1.825
# 220        NaN  Female 1991-06-17        12:49:00   71945    5.560
# 253        NaN     NaN 2003-04-28        03:01:00  113732   10.391
# 257        NaN    Male 1999-11-25        06:16:00   42676   15.517
# 266        NaN  Female 2009-08-05        08:14:00  115145   14.063
# 267        NaN    Male 2005-02-04        01:01:00   40451   16.044
# 269        NaN  Female 1992-08-02        08:35:00  145316   18.517
# 320        NaN  Female 2008-07-08        11:40:00   62960   14.356
# 329        NaN    Male 2010-01-27        02:57:00   87760   14.987
# 352        NaN    Male 2011-10-09        09:29:00   69906    4.844
# 353        NaN    Male 1997-04-22        09:36:00   65078    3.095
# 374        NaN  Female 2006-12-31        11:02:00   81444    3.171
# 379        NaN  Female 2002-09-18        12:39:00  118906    4.537
# 416        NaN    Male 2008-06-29        05:23:00  111043    5.966
# 444        NaN    Male 2016-05-24        09:17:00   76409    7.008
# 454        NaN    Male 1995-02-21        12:26:00  136602   10.429
# 481        NaN  Female 2013-04-27        06:40:00   93847    1.085
# 483        NaN  Female 1992-04-26        08:01:00  115436    3.099
# 504        NaN  Female 2014-06-24        10:05:00   38275   10.494
# 505        NaN    Male 1980-04-20        01:17:00   71520   13.248
# 521        NaN     NaN 1981-09-25        09:59:00   83895   17.971
# 540        NaN  Female 2009-12-02        03:30:00   84746    4.820
# 574        NaN  Female 2009-01-13        01:01:00  118736    7.421
# 599        NaN  Female 1990-10-11        10:57:00   98385   10.925
# 607        NaN    Male 1983-10-13        11:59:00  139754   12.740
# 608        NaN  Female 1993-10-24        05:17:00  116236   17.274
# 628        NaN     NaN 1988-09-02        12:49:00  147309    1.702
# 674        NaN    Male 2012-08-28        07:56:00   88733    1.932
# 685        NaN    Male 1989-10-20        09:37:00   88086   19.387
# 687        NaN    Male 1996-12-27        07:07:00  139959    8.992
# 697        NaN    Male 1990-05-23        02:09:00  136655    9.801
# 709        NaN    Male 1995-04-07        04:32:00   60411   12.048
# 733        NaN    Male 2009-06-17        01:00:00  136681    3.655
# 734        NaN  Female 1994-12-18        08:42:00  138807    1.400
# 773        NaN    Male 1986-10-24        09:23:00   47176   10.736
# 782        NaN    Male 1986-05-06        04:41:00   74104   17.680
# 783        NaN     NaN 1991-04-15        03:39:00  132505   13.592
# 785        NaN  Female 1982-07-24        12:00:00   57811    8.941
# 812        NaN    Male 1994-12-13        10:34:00  141311    5.478
# 821        NaN  Female 1980-12-27        02:27:00   80399   12.254
# 823        NaN    Male 2009-11-12        02:30:00  109411    9.494
# 877        NaN    Male 1980-09-05        07:36:00  114896   13.823
# 890        NaN    Male 2015-11-24        03:11:00  145329    7.100
# 902        NaN    Male 2001-05-23        07:52:00  103877    6.322
# 925        NaN  Female 2000-08-23        04:19:00   95866   19.388
# 946        NaN  Female 1985-09-15        01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30        03:07:00  107351    5.329
#
#      Senior Management                  Team
# 7                 True               Finance
# 25                True       Client Services
# 39                True       Client Services
# 51                True                 Sales
# 62                True             Marketing
# 116               True                 Legal
# 149               True          Distribution
# 157               True               Product
# 165               True                 Legal
# 166               True                 Sales
# 174               True       Client Services
# 186               True                 Sales
# 220               True             Marketing
# 253               True                 Sales
# 257               True                 Sales
# 266               True          Distribution
# 267               True          Distribution
# 269               True       Human Resources
# 320               True                 Sales
# 329               True           Engineering
# 352               True           Engineering
# 353               True             Marketing
# 374               True          Distribution
# 379               True             Marketing
# 416               True          Distribution
# 444               True          Distribution
# 454               True             Marketing
# 481               True  Business Development
# 483               True       Human Resources
# 504               True          Distribution
# 505               True           Engineering
# 521               True           Engineering
# 540               True               Finance
# 574               True       Client Services
# 599               True       Human Resources
# 607               True                 Sales
# 608               True           Engineering
# 628               True          Distribution
# 674               True       Human Resources
# 685               True               Finance
# 687               True          Distribution
# 697               True          Distribution
# 709               True       Human Resources
# 733               True  Business Development
# 734               True       Human Resources
# 773               True               Finance
# 782               True       Client Services
# 783               True               Product
# 785               True             Marketing
# 812               True               Product
# 821               True          Distribution
# 823               True           Engineering
# 877               True       Client Services
# 890               True               Finance
# 902               True          Distribution
# 925               True                 Sales
# 946               True          Distribution
# 947               True             Marketing

# %%
employees[employees["Salary"].between(60000, 70000)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 10      Louise  Female 1980-08-12        09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22        07:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28        01:08:00   66582   11.308
# ..         ...     ...        ...             ...     ...      ...
# 965  Catherine  Female 1989-09-25        01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03        08:54:00   63571   15.397
# 974      Harry    Male 2011-08-30        06:31:00   67656   16.455
# 978       Sean    Male 1983-01-17        02:23:00   66146   11.178
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
employees[employees["Start Date"].between("1991-01-01", "1992-01-01")]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 27       Scott     NaN 1991-07-11        06:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02        01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27        01:59:00   64088    6.155
# 116        NaN    Male 1991-06-22        08:58:00   76189   18.988
# 148    Patrick     NaN 1991-07-14        02:24:00  124488   14.837
# 166        NaN  Female 1991-07-09        06:52:00   42341    7.014
# 172       Sara  Female 1991-09-23        06:17:00   97058    9.402
# 220        NaN  Female 1991-06-17        12:49:00   71945    5.560
# 245     Victor    Male 1991-04-11        07:44:00   70817   17.138
# 277     Brenda     NaN 1991-05-29        06:32:00   82439   19.062
# 313       Judy  Female 1991-07-01        02:33:00  109510   13.457
# 328     Samuel    Male 1991-12-19        02:54:00   76076    5.319
# 339    Michael    Male 1991-11-22        12:57:00   98753   16.443
# 537    Cynthia  Female 1991-09-14        01:08:00   51633   13.472
# 552    Barbara  Female 1991-09-02        03:41:00  127297   11.905
# 603       Carl     NaN 1991-10-26        08:11:00  100888   12.490
# 639     Amanda     NaN 1991-08-11        02:15:00   46665   19.391
# 704     Thomas    Male 1991-09-07        09:51:00   65251   11.211
# 725     Jeremy    Male 1991-05-19        01:40:00  131513    1.876
# 766     Justin    Male 1991-07-25        12:45:00  112975    9.699
# 771      Peter    Male 1991-05-22        01:39:00  102577   12.026
# 783        NaN     NaN 1991-04-15        03:39:00  132505   13.592
# 891    Timothy    Male 1991-08-25        10:37:00   92587    8.475
# 895     Janice     NaN 1991-11-19        06:02:00  139791   16.968
# 909     Donald    Male 1991-08-01        02:25:00   61999    6.466
# 923      Irene     NaN 1991-02-28        10:23:00  135369    4.380
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
#
#      Senior Management                  Team
# 27               False                 Legal
# 75                True       Human Resources
# 88                True                 Legal
# 116               True                 Legal
# 148               True                 Sales
# 166               True                 Sales
# 172              False               Finance
# 220               True             Marketing
# 245              False           Engineering
# 277              False                 Sales
# 313               True                 Legal
# 328               True               Finance
# 339               True       Human Resources
# 537               True  Business Development
# 552               True               Product
# 603               True  Business Development
# 639               True       Client Services
# 704              False          Distribution
# 725               True               Finance
# 766              False       Human Resources
# 771               True               Product
# 783               True               Product
# 891              False               Finance
# 895              False  Business Development
# 909              False               Product
# 923              False  Business Development
# 989              False                 Legal

# %%
employees["First Name"].duplicated().sum()
# Out:
# np.int64(799)

# %%
employees["Senior Management"].duplicated().sum()
# Out:
# np.int64(998)

# %%
employees[employees["First Name"].duplicated()]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 23         NaN   Male 2012-06-14        04:19:00  125792    5.042
# 25         NaN   Male 2012-10-08        01:12:00   37076   18.576
# 32         NaN   Male 1998-08-21        02:27:00  122340    6.417
# 34       Jerry   Male 2004-01-10        12:56:00   95734   19.096
# 39         NaN   Male 2016-01-29        02:33:00  122173    7.797
# ..         ...    ...        ...             ...     ...      ...
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 23                True                   NaN
# 25                True       Client Services
# 32                True                   NaN
# 34               False       Client Services
# 39                True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [799 rows x 8 columns]

# %%
employees[employees["First Name"].duplicated(keep="first")]
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 23         NaN   Male 2012-06-14        04:19:00  125792    5.042
# 25         NaN   Male 2012-10-08        01:12:00   37076   18.576
# 32         NaN   Male 1998-08-21        02:27:00  122340    6.417
# 34       Jerry   Male 2004-01-10        12:56:00   95734   19.096
# 39         NaN   Male 2016-01-29        02:33:00  122173    7.797
# ..         ...    ...        ...             ...     ...      ...
# 995      Henry    NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip   Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert   Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 23                True                   NaN
# 25                True       Client Services
# 32                True                   NaN
# 34               False       Client Services
# 39                True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [799 rows x 8 columns]

# %%
employees[employees["First Name"].duplicated(keep="last")]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 959     Albert    Male 1992-09-19        02:35:00   45094    5.850
# 960    Stephen    Male 1989-10-29        11:34:00   93997   18.093
# 970      Alice  Female 1988-09-03        08:54:00   63571   15.397
# 973    Russell    Male 2013-05-10        11:08:00  137359   11.105
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 959               True  Business Development
# 960               True  Business Development
# 970               True               Product
# 973              False  Business Development
# 982               True       Human Resources
#
# [799 rows x 8 columns]

# %%
employees[employees["First Name"].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [991 rows x 8 columns]

# %%
employees[~employees["First Name"].duplicated(keep=False)]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18        09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19        03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11        10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24        10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07        10:47:00   93901   17.821
# 832      Keith    Male 2003-02-12        03:02:00  120672   19.467
# 887      David    Male 2009-12-05        08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %%
employees.drop_duplicates()
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees.drop_duplicates("Team")
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 4                True       Client Services
# 5               False                 Legal
# 6                True               Product
# 8                True           Engineering
# 9                True  Business Development
# 12               True       Human Resources
# 13              False                 Sales
# 40               True          Distribution

# %%
employees.drop_duplicates("Team", keep="first")
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 4       Larry    Male 1998-01-24        04:47:00  101004    1.389
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 2               False               Finance
# 4                True       Client Services
# 5               False                 Legal
# 6                True               Product
# 8                True           Engineering
# 9                True  Business Development
# 12               True       Human Resources
# 13              False                 Sales
# 40               True          Distribution

# %%
employees.drop_duplicates("Team", keep="last")
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 951        NaN  Female 2010-09-14        05:19:00  143638    9.662
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 990      Robin  Female 1987-07-24        01:35:00  100765   10.982
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 951               True                   NaN
# 988              False       Human Resources
# 989              False                 Legal
# 990               True       Client Services
# 993               True           Engineering
# 994               True             Marketing
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales

# %%
employees.drop_duplicates("Team", keep=False)
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %%
employees.drop_duplicates("First Name", keep=False)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 8       Angela  Female 2005-11-22        06:29:00   95570   18.523
# 33        Jean  Female 1993-12-18        09:07:00  119082   16.180
# 190      Carol  Female 1996-03-19        03:39:00   57783    9.129
# 291      Tammy  Female 1984-11-11        10:30:00  132839   17.463
# 495     Eugene    Male 1984-05-24        10:54:00   81077    2.117
# 688      Brian    Male 2007-04-07        10:47:00   93901   17.821
# 832      Keith    Male 2003-02-12        03:02:00  120672   19.467
# 887      David    Male 2009-12-05        08:48:00   92242   15.407
#
#      Senior Management                  Team
# 5                False                 Legal
# 8                 True           Engineering
# 33               False  Business Development
# 190              False               Finance
# 291               True       Client Services
# 495              False                 Sales
# 688               True                 Legal
# 832              False                 Legal
# 887              False                 Legal

# %%
employees.drop_duplicates(["Senior Management", "Team"]).sort_values("Team")
# Out:
#    First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 33       Jean  Female 1993-12-18        09:07:00  119082   16.180
# 9     Frances  Female 2002-08-08        06:51:00  139852    7.524
# 4       Larry    Male 1998-01-24        04:47:00  101004    1.389
# 18      Diana  Female 1981-10-23        10:27:00  132940   19.082
# 60      Paula     NaN 2005-11-23        02:01:00   48866    4.271
# 40    Michael    Male 2008-10-10        11:25:00   99283    2.665
# 8      Angela  Female 2005-11-22        06:29:00   95570   18.523
# 54       Sara  Female 2007-08-15        09:23:00   83677    8.999
# 2       Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3       Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 16     Jeremy    Male 2010-09-21        05:56:00   90370    7.369
# 12    Brandon    Male 1980-12-01        01:08:00  112807   17.492
# 11      Julie  Female 1997-10-26        03:19:00  102508   12.637
# 5      Dennis    Male 1987-04-18        01:35:00  115163   10.125
# 21    Matthew    Male 1995-09-05        02:12:00  100612   13.645
# 0     Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 6        Ruby  Female 1987-08-17        04:20:00   65476   10.012
# 15    Lillian  Female 2016-06-05        06:09:00   59414    1.256
# 13       Gary    Male 2008-01-27        11:40:00  109831    5.831
# 45      Roger    Male 1980-04-17        11:32:00   88010   13.886
# 1      Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 91      James     NaN 2005-01-26        11:00:00  128771    8.309
#
#     Senior Management                  Team
# 33              False  Business Development
# 9                True  Business Development
# 4                True       Client Services
# 18              False       Client Services
# 60              False          Distribution
# 40               True          Distribution
# 8                True           Engineering
# 54              False           Engineering
# 2               False               Finance
# 3                True               Finance
# 16              False       Human Resources
# 12               True       Human Resources
# 11               True                 Legal
# 5               False                 Legal
# 21              False             Marketing
# 0                True             Marketing
# 6                True               Product
# 15              False               Product
# 13              False                 Sales
# 45               True                 Sales
# 1                True                   NaN
# 91              False                   NaN

# %%
employees.drop_duplicates(["Senior Management", "Team"], keep="last").sort_values("Team")
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 971    Patrick    Male 2002-12-30        02:01:00   75423    5.368
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 965  Catherine  Female 1989-09-25        01:31:00   68164   18.393
# 990      Robin  Female 1987-07-24        01:35:00  100765   10.982
# 946        NaN  Female 1985-09-15        01:50:00  133472   16.941
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 993       Tina  Female 1997-05-15        03:53:00   56450   19.040
# 984      Maria  Female 2011-10-15        04:53:00   43455   13.040
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 992    Anthony    Male 2011-10-16        08:35:00  112769   11.625
# 988      Alice  Female 2004-10-05        09:34:00   47638   11.209
# 982       Rose  Female 1982-04-06        10:43:00   91411    8.639
# 976     Denise  Female 1992-10-19        05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10        04:58:00   38344    3.794
# 986      Donna  Female 1982-11-26        07:04:00   82871   17.999
# 994     George    Male 2013-06-21        05:47:00   98874    4.479
# 979     Ernest    Male 2013-07-20        06:41:00  142935   13.198
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 975      Susan  Female 1995-04-07        10:05:00   92436   12.467
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
# 912        Joe    Male 1998-12-08        10:28:00  126120    1.020
# 951        NaN  Female 2010-09-14        05:19:00  143638    9.662
#
#      Senior Management                  Team
# 971               True  Business Development
# 998              False  Business Development
# 965              False       Client Services
# 990               True       Client Services
# 946               True          Distribution
# 995              False          Distribution
# 993               True           Engineering
# 984              False           Engineering
# 996              False               Finance
# 992               True               Finance
# 988              False       Human Resources
# 982               True       Human Resources
# 976               True                 Legal
# 989              False                 Legal
# 986              False             Marketing
# 994               True             Marketing
# 979               True               Product
# 997              False               Product
# 975              False                 Sales
# 999               True                 Sales
# 912              False                   NaN
# 951               True                   NaN

# %%
employees["Gender"].unique()
# Out:
# ['Male', 'Female', NaN]
# Categories (2, object): ['Female', 'Male']

# %%
type(employees["Gender"].unique())
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
employees["Team"].unique()
# Out:
# array(['Marketing', nan, 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
type(employees["Team"].unique())
# Out:
# numpy.ndarray

# %%
employees["Team"].nunique()
# Out:
# 10

# %%
employees["Team"].nunique(dropna=True)
# Out:
# 10

# %%
employees["Team"].nunique(dropna=False)
# Out:
# 11

# %%
employees.nunique()
# Out:
# First Name           200
# Gender                 2
# Start Date           972
# Last Login Time      542
# Salary               995
# Bonus %              971
# Senior Management      2
# Team                  10
# dtype: int64

# %% [markdown]
# ## The set_index and reset_index Methods
# - The `set_index` method sets an existing column as the index of the DataFrame.
# - The `reset_index` method sets the standard ascending numeric index as the index of the DataFrame.

# %%
employees
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06        12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31        06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23        11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04        01:00:00  138705    9.340
# 4        Larry    Male 1998-01-24        04:47:00  101004    1.389
# ..         ...     ...        ...             ...     ...      ...
# 995      Henry     NaN 2014-11-23        06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31        06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20        12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20        04:45:00   60500   11.985
# 999     Albert    Male 2012-05-15        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 8 columns]

# %%
employees = employees.reset_index().set_index("Start Date")
employees.head()
# Out:
#             index First Name  Gender Last Login Time  Salary  Bonus %  \
# Start Date
# 1993-08-06      0    Douglas    Male        12:42:00   97308    6.945
# 1996-03-31      1     Thomas    Male        06:53:00   61933    4.170
# 1993-04-23      2      Maria  Female        11:17:00  130590   11.858
# 2005-03-04      3      Jerry    Male        01:00:00  138705    9.340
# 1998-01-24      4      Larry    Male        04:47:00  101004    1.389
#
#             Senior Management             Team
# Start Date
# 1993-08-06               True        Marketing
# 1996-03-31               True              NaN
# 1993-04-23              False          Finance
# 2005-03-04               True          Finance
# 1998-01-24               True  Client Services

# %%
employees = employees.reset_index()
employees.head()
# Out:
#   Start Date  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0 1993-08-06      0    Douglas    Male        12:42:00   97308    6.945
# 1 1996-03-31      1     Thomas    Male        06:53:00   61933    4.170
# 2 1993-04-23      2      Maria  Female        11:17:00  130590   11.858
# 3 2005-03-04      3      Jerry    Male        01:00:00  138705    9.340
# 4 1998-01-24      4      Larry    Male        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees = employees.reset_index().set_index("Start Date")
employees.head()
# Out:
#             level_0  index First Name  Gender Last Login Time  Salary  \
# Start Date
# 1993-08-06        0      0    Douglas    Male        12:42:00   97308
# 1996-03-31        1      1     Thomas    Male        06:53:00   61933
# 1993-04-23        2      2      Maria  Female        11:17:00  130590
# 2005-03-04        3      3      Jerry    Male        01:00:00  138705
# 1998-01-24        4      4      Larry    Male        04:47:00  101004
#
#             Bonus %  Senior Management             Team
# Start Date
# 1993-08-06    6.945               True        Marketing
# 1996-03-31    4.170               True              NaN
# 1993-04-23   11.858              False          Finance
# 2005-03-04    9.340               True          Finance
# 1998-01-24    1.389               True  Client Services

# %%
employees = employees.reset_index(drop=True)
employees.head()
# Out:
#    level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0        0      0    Douglas    Male        12:42:00   97308    6.945
# 1        1      1     Thomas    Male        06:53:00   61933    4.170
# 2        2      2      Maria  Female        11:17:00  130590   11.858
# 3        3      3      Jerry    Male        01:00:00  138705    9.340
# 4        4      4      Larry    Male        04:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %%
employees.iloc[5]
# Out:
# level_0                     5
# index                       5
# First Name             Dennis
# Gender                   Male
# Last Login Time      01:35:00
# Salary                 115163
# Bonus %                10.125
# Senior Management       False
# Team                    Legal
# Name: 5, dtype: object

# %%
employees.iloc[[15, 20]]
# Out:
#     level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 15       15     15    Lillian  Female        06:09:00   59414    1.256
# 20       20     20       Lois     NaN        07:18:00   64714    4.934
#
#     Senior Management     Team
# 15              False  Product
# 20               True    Legal

# %%
employees.iloc[4:8]
# Out:
#    level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 4        4      4      Larry    Male        04:47:00  101004    1.389
# 5        5      5     Dennis    Male        01:35:00  115163   10.125
# 6        6      6       Ruby  Female        04:20:00   65476   10.012
# 7        7      7        NaN  Female        10:43:00   45906   11.598
#
#    Senior Management             Team
# 4               True  Client Services
# 5              False            Legal
# 6               True          Product
# 7               True          Finance

# %%
employees.iloc[:6]
# Out:
#    level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0        0      0    Douglas    Male        12:42:00   97308    6.945
# 1        1      1     Thomas    Male        06:53:00   61933    4.170
# 2        2      2      Maria  Female        11:17:00  130590   11.858
# 3        3      3      Jerry    Male        01:00:00  138705    9.340
# 4        4      4      Larry    Male        04:47:00  101004    1.389
# 5        5      5     Dennis    Male        01:35:00  115163   10.125
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services
# 5              False            Legal

# %%
employees.iloc[980:]
# Out:
#      level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 980      980    980   Kimberly  Female        12:57:00   46233    8.862
# 981      981    981      James    Male        05:19:00  148985   19.280
# 982      982    982       Rose  Female        10:43:00   91411    8.639
# 983      983    983       John    Male        10:35:00  146907   11.738
# 984      984    984      Maria  Female        04:53:00   43455   13.040
# 985      985    985    Stephen     NaN        08:10:00   85668    1.909
# 986      986    986      Donna  Female        07:04:00   82871   17.999
# 987      987    987     Gloria  Female        05:08:00  136709   10.331
# 988      988    988      Alice  Female        09:34:00   47638   11.209
# 989      989    989     Justin     NaN        04:58:00   38344    3.794
# 990      990    990      Robin  Female        01:35:00  100765   10.982
# 991      991    991       Rose  Female        05:12:00  134505   11.051
# 992      992    992    Anthony    Male        08:35:00  112769   11.625
# 993      993    993       Tina  Female        03:53:00   56450   19.040
# 994      994    994     George    Male        05:47:00   98874    4.479
# 995      995    995      Henry     NaN        06:09:00  132483   16.655
# 996      996    996    Phillip    Male        06:30:00   42392   19.675
# 997      997    997    Russell    Male        12:39:00   96914    1.421
# 998      998    998      Larry    Male        04:45:00   60500   11.985
# 999      999    999     Albert    Male        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 980               True           Engineering
# 981              False                 Legal
# 982               True       Human Resources
# 983              False           Engineering
# 984              False           Engineering
# 985              False                 Legal
# 986              False             Marketing
# 987               True               Finance
# 988              False       Human Resources
# 989              False                 Legal
# 990               True       Client Services
# 991               True             Marketing
# 992               True               Finance
# 993               True           Engineering
# 994               True             Marketing
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales

# %%
employees.iloc[0, 2]
# Out:
# 'Douglas'

# %%
employees.iloc[3, 5]
# Out:
# np.int64(138705)

# %%
employees.iloc[[0, 2], 3]
# Out:
# 0      Male
# 2    Female
# Name: Gender, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
employees.iloc[[0, 2], [3, 5]]
# Out:
#    Gender  Salary
# 0    Male   97308
# 2  Female  130590

# %%
employees.iloc[:7, :3]
# Out:
#    level_0  index First Name
# 0        0      0    Douglas
# 1        1      1     Thomas
# 2        2      2      Maria
# 3        3      3      Jerry
# 4        4      4      Larry
# 5        5      5     Dennis
# 6        6      6       Ruby

# %%
employees
# Out:
#      level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0          0      0    Douglas    Male        12:42:00   97308    6.945
# 1          1      1     Thomas    Male        06:53:00   61933    4.170
# 2          2      2      Maria  Female        11:17:00  130590   11.858
# 3          3      3      Jerry    Male        01:00:00  138705    9.340
# 4          4      4      Larry    Male        04:47:00  101004    1.389
# ..       ...    ...        ...     ...             ...     ...      ...
# 995      995    995      Henry     NaN        06:09:00  132483   16.655
# 996      996    996    Phillip    Male        06:30:00   42392   19.675
# 997      997    997    Russell    Male        12:39:00   96914    1.421
# 998      998    998      Larry    Male        04:45:00   60500   11.985
# 999      999    999     Albert    Male        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 9 columns]

# %%
employees.loc[0 , "First Name"] = "Connery"

# %%
employees
# Out:
#      level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0          0      0    Connery    Male        12:42:00   97308    6.945
# 1          1      1     Thomas    Male        06:53:00   61933    4.170
# 2          2      2      Maria  Female        11:17:00  130590   11.858
# 3          3      3      Jerry    Male        01:00:00  138705    9.340
# 4          4      4      Larry    Male        04:47:00  101004    1.389
# ..       ...    ...        ...     ...             ...     ...      ...
# 995      995    995      Henry     NaN        06:09:00  132483   16.655
# 996      996    996    Phillip    Male        06:30:00   42392   19.675
# 997      997    997    Russell    Male        12:39:00   96914    1.421
# 998      998    998      Larry    Male        04:45:00   60500   11.985
# 999      999    999     Albert    Male        06:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 995              False          Distribution
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [1000 rows x 9 columns]

# %%
employees.drop(columns=["level_0"])
# Out:
#      index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0        0    Connery    Male        12:42:00   97308    6.945
# 1        1     Thomas    Male        06:53:00   61933    4.170
# 2        2      Maria  Female        11:17:00  130590   11.858
# 3        3      Jerry    Male        01:00:00  138705    9.340
# 4        4      Larry    Male        04:47:00  101004    1.389
# ..     ...        ...     ...             ...     ...      ...
# 995    995      Henry     NaN        06:09:00  132483   16.655
# 996    996    Phillip    Male        06:30:00   42392   19.675
# 997    997    Russell    Male        12:39:00   96914    1.421
# 998    998      Larry    Male        04:45:00   60500   11.985
# 999    999     Albert    Male        06:24:00  129949   10.169
#
#      Senior Management                  Team  Marketing  NaN  Finance  \
# 0                 True             Marketing  Marketing  NaN  Finance
# 1                 True                   NaN  Marketing  NaN  Finance
# 2                False               Finance  Marketing  NaN  Finance
# 3                 True               Finance  Marketing  NaN  Finance
# 4                 True       Client Services  Marketing  NaN  Finance
# ..                 ...                   ...        ...  ...      ...
# 995              False          Distribution  Marketing  NaN  Finance
# 996              False               Finance  Marketing  NaN  Finance
# 997              False               Product  Marketing  NaN  Finance
# 998              False  Business Development  Marketing  NaN  Finance
# 999               True                 Sales  Marketing  NaN  Finance
#
#      Client Services  Legal  Product  Engineering  Business Development  \
# 0    Client Services  Legal  Product  Engineering  Business Development
# 1    Client Services  Legal  Product  Engineering  Business Development
# 2    Client Services  Legal  Product  Engineering  Business Development
# 3    Client Services  Legal  Product  Engineering  Business Development
# 4    Client Services  Legal  Product  Engineering  Business Development
# ..               ...    ...      ...          ...                   ...
# 995  Client Services  Legal  Product  Engineering  Business Development
# 996  Client Services  Legal  Product  Engineering  Business Development
# 997  Client Services  Legal  Product  Engineering  Business Development
# 998  Client Services  Legal  Product  Engineering  Business Development
# 999  Client Services  Legal  Product  Engineering  Business Development
#
#      Human Resources  Sales  Distribution
# 0    Human Resources  Sales  Distribution
# 1    Human Resources  Sales  Distribution
# 2    Human Resources  Sales  Distribution
# 3    Human Resources  Sales  Distribution
# 4    Human Resources  Sales  Distribution
# ..               ...    ...           ...
# 995  Human Resources  Sales  Distribution
# 996  Human Resources  Sales  Distribution
# 997  Human Resources  Sales  Distribution
# 998  Human Resources  Sales  Distribution
# 999  Human Resources  Sales  Distribution
#
# [1000 rows x 19 columns]

# %%
employees
# Out:
#      level_0  index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0          0      0    Connery    Male        12:42:00   97308    6.945
# 1          1      1     Thomas    Male        06:53:00   61933    4.170
# 2          2      2      Maria  Female        11:17:00  130590   11.858
# 3          3      3      Jerry    Male        01:00:00  138705    9.340
# 4          4      4      Larry    Male        04:47:00  101004    1.389
# ..       ...    ...        ...     ...             ...     ...      ...
# 995      995    995      Henry     NaN        06:09:00  132483   16.655
# 996      996    996    Phillip    Male        06:30:00   42392   19.675
# 997      997    997    Russell    Male        12:39:00   96914    1.421
# 998      998    998      Larry    Male        04:45:00   60500   11.985
# 999      999    999     Albert    Male        06:24:00  129949   10.169
#
#      Senior Management                  Team  Marketing  NaN  Finance  \
# 0                 True             Marketing  Marketing  NaN  Finance
# 1                 True                   NaN  Marketing  NaN  Finance
# 2                False               Finance  Marketing  NaN  Finance
# 3                 True               Finance  Marketing  NaN  Finance
# 4                 True       Client Services  Marketing  NaN  Finance
# ..                 ...                   ...        ...  ...      ...
# 995              False          Distribution  Marketing  NaN  Finance
# 996              False               Finance  Marketing  NaN  Finance
# 997              False               Product  Marketing  NaN  Finance
# 998              False  Business Development  Marketing  NaN  Finance
# 999               True                 Sales  Marketing  NaN  Finance
#
#      Client Services  Legal  Product  Engineering  Business Development  \
# 0    Client Services  Legal  Product  Engineering  Business Development
# 1    Client Services  Legal  Product  Engineering  Business Development
# 2    Client Services  Legal  Product  Engineering  Business Development
# 3    Client Services  Legal  Product  Engineering  Business Development
# 4    Client Services  Legal  Product  Engineering  Business Development
# ..               ...    ...      ...          ...                   ...
# 995  Client Services  Legal  Product  Engineering  Business Development
# 996  Client Services  Legal  Product  Engineering  Business Development
# 997  Client Services  Legal  Product  Engineering  Business Development
# 998  Client Services  Legal  Product  Engineering  Business Development
# 999  Client Services  Legal  Product  Engineering  Business Development
#
#      Human Resources  Sales  Distribution
# 0    Human Resources  Sales  Distribution
# 1    Human Resources  Sales  Distribution
# 2    Human Resources  Sales  Distribution
# 3    Human Resources  Sales  Distribution
# 4    Human Resources  Sales  Distribution
# ..               ...    ...           ...
# 995  Human Resources  Sales  Distribution
# 996  Human Resources  Sales  Distribution
# 997  Human Resources  Sales  Distribution
# 998  Human Resources  Sales  Distribution
# 999  Human Resources  Sales  Distribution
#
# [1000 rows x 20 columns]

# %%
employees.drop(columns=["level_0"], inplace=True)

# %%
employees
# Out:
#      index First Name  Gender Last Login Time  Salary  Bonus %  \
# 0        0    Connery    Male        12:42:00   97308    6.945
# 1        1     Thomas    Male        06:53:00   61933    4.170
# 2        2      Maria  Female        11:17:00  130590   11.858
# 3        3      Jerry    Male        01:00:00  138705    9.340
# 4        4      Larry    Male        04:47:00  101004    1.389
# ..     ...        ...     ...             ...     ...      ...
# 995    995      Henry     NaN        06:09:00  132483   16.655
# 996    996    Phillip    Male        06:30:00   42392   19.675
# 997    997    Russell    Male        12:39:00   96914    1.421
# 998    998      Larry    Male        04:45:00   60500   11.985
# 999    999     Albert    Male        06:24:00  129949   10.169
#
#      Senior Management                  Team  Marketing  NaN  Finance  \
# 0                 True             Marketing  Marketing  NaN  Finance
# 1                 True                   NaN  Marketing  NaN  Finance
# 2                False               Finance  Marketing  NaN  Finance
# 3                 True               Finance  Marketing  NaN  Finance
# 4                 True       Client Services  Marketing  NaN  Finance
# ..                 ...                   ...        ...  ...      ...
# 995              False          Distribution  Marketing  NaN  Finance
# 996              False               Finance  Marketing  NaN  Finance
# 997              False               Product  Marketing  NaN  Finance
# 998              False  Business Development  Marketing  NaN  Finance
# 999               True                 Sales  Marketing  NaN  Finance
#
#      Client Services  Legal  Product  Engineering  Business Development  \
# 0    Client Services  Legal  Product  Engineering  Business Development
# 1    Client Services  Legal  Product  Engineering  Business Development
# 2    Client Services  Legal  Product  Engineering  Business Development
# 3    Client Services  Legal  Product  Engineering  Business Development
# 4    Client Services  Legal  Product  Engineering  Business Development
# ..               ...    ...      ...          ...                   ...
# 995  Client Services  Legal  Product  Engineering  Business Development
# 996  Client Services  Legal  Product  Engineering  Business Development
# 997  Client Services  Legal  Product  Engineering  Business Development
# 998  Client Services  Legal  Product  Engineering  Business Development
# 999  Client Services  Legal  Product  Engineering  Business Development
#
#      Human Resources  Sales  Distribution
# 0    Human Resources  Sales  Distribution
# 1    Human Resources  Sales  Distribution
# 2    Human Resources  Sales  Distribution
# 3    Human Resources  Sales  Distribution
# 4    Human Resources  Sales  Distribution
# ..               ...    ...           ...
# 995  Human Resources  Sales  Distribution
# 996  Human Resources  Sales  Distribution
# 997  Human Resources  Sales  Distribution
# 998  Human Resources  Sales  Distribution
# 999  Human Resources  Sales  Distribution
#
# [1000 rows x 19 columns]

# %%
employees.sample()
# Out:
#      index First Name Gender Last Login Time  Salary  Bonus %  \
# 302    302       Adam   Male        11:59:00   71276    5.027
#
#      Senior Management             Team  Marketing  NaN  Finance  \
# 302               True  Human Resources  Marketing  NaN  Finance
#
#      Client Services  Legal  Product  Engineering  Business Development  \
# 302  Client Services  Legal  Product  Engineering  Business Development
#
#      Human Resources  Sales  Distribution
# 302  Human Resources  Sales  Distribution

# %%
employees.sample(n=5)
# Out:
#      index First Name  Gender Last Login Time  Salary  Bonus %  \
# 273    273   Nicholas    Male        08:21:00   74669    1.113
# 916    916    Marilyn  Female        07:18:00  118369    7.696
# 209    209      Emily  Female        11:25:00   89434   11.295
# 941    941    William    Male        08:33:00  104840   15.653
# 204    204     Willie    Male        09:45:00   55281    4.935
#
#      Senior Management                  Team  Marketing  NaN  Finance  \
# 273               True               Product  Marketing  NaN  Finance
# 916               True  Business Development  Marketing  NaN  Finance
# 209              False           Engineering  Marketing  NaN  Finance
# 941               True           Engineering  Marketing  NaN  Finance
# 204               True             Marketing  Marketing  NaN  Finance
#
#      Client Services  Legal  Product  Engineering  Business Development  \
# 273  Client Services  Legal  Product  Engineering  Business Development
# 916  Client Services  Legal  Product  Engineering  Business Development
# 209  Client Services  Legal  Product  Engineering  Business Development
# 941  Client Services  Legal  Product  Engineering  Business Development
# 204  Client Services  Legal  Product  Engineering  Business Development
#
#      Human Resources  Sales  Distribution
# 273  Human Resources  Sales  Distribution
# 916  Human Resources  Sales  Distribution
# 209  Human Resources  Sales  Distribution
# 941  Human Resources  Sales  Distribution
# 204  Human Resources  Sales  Distribution

# %%
employees.sample(n=3, axis="rows")
# Out:
#      index First Name  Gender Last Login Time  Salary  Bonus %  \
# 47      47      Kathy  Female        04:51:00   66820    9.000
# 652    652     Willie    Male        05:39:00  141932    1.017
# 576    576    Michael    Male        05:35:00   35013   14.879
#
#      Senior Management             Team  Marketing  NaN  Finance  \
# 47                True  Client Services  Marketing  NaN  Finance
# 652               True      Engineering  Marketing  NaN  Finance
# 576              False          Product  Marketing  NaN  Finance
#
#      Client Services  Legal  Product  Engineering  Business Development  \
# 47   Client Services  Legal  Product  Engineering  Business Development
# 652  Client Services  Legal  Product  Engineering  Business Development
# 576  Client Services  Legal  Product  Engineering  Business Development
#
#      Human Resources  Sales  Distribution
# 47   Human Resources  Sales  Distribution
# 652  Human Resources  Sales  Distribution
# 576  Human Resources  Sales  Distribution

# %%
employees.sample(n=2, axis="columns")
# Out:
#      Finance  Gender
# 0    Finance    Male
# 1    Finance    Male
# 2    Finance  Female
# 3    Finance    Male
# 4    Finance    Male
# ..       ...     ...
# 995  Finance     NaN
# 996  Finance    Male
# 997  Finance    Male
# 998  Finance    Male
# 999  Finance    Male
#
# [1000 rows x 2 columns]

# %% [markdown]
# ## The nsmallest and nlargest Methods
# - The `nlargest` method returns a specified number of rows with the largest values from a given column.
# - The `nsmallest` method returns rows with the smallest values from a given column.
# - The `nlargest` and `nsmallest` methods are more efficient than sorting the entire **DataFrame**.

# %%
employees = pd.read_csv("employees.csv")
employees.sort_values("Salary", ascending=False).head(4)
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 644  Katherine  Female  8/13/1996        12:21 AM  149908   18.912
# 429       Rose  Female  5/28/2015         8:40 AM  149903    5.630
# 828    Cynthia  Female  7/12/2006         8:55 AM  149684    7.864
# 186        NaN  Female  2/23/2005         9:50 PM  149654    1.825
#
#     Senior Management             Team
# 644             False          Finance
# 429             False  Human Resources
# 828             False          Product
# 186               NaN            Sales

# %%
employees["Salary"].nlargest(4)
# Out:
# 644    149908
# 429    149903
# 828    149684
# 186    149654
# Name: Salary, dtype: int64

# %%
employees["Salary"].nsmallest(4)
# Out:
# 576    35013
# 238    35061
# 82     35095
# 63     35203
# Name: Salary, dtype: int64

# %%
employees.sort_values("Salary", ascending=True).head(4)
# Out:
#     First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 576    Michael   Male  7/30/1993         5:35 PM   35013   14.879
# 238      Kevin   Male  3/25/1982         7:31 AM   35061    5.128
# 82      Steven   Male  3/30/1980         9:20 PM   35095    8.379
# 63     Matthew   Male   1/2/2013        10:33 PM   35203   18.040
#
#     Senior Management             Team
# 576             False          Product
# 238             False            Legal
# 82               True  Client Services
# 63              False  Human Resources

# %%
len(Team)
# Out:
# 10

# %%
Team.size()
# Out:
# Team
# Business Development    101
# Client Services         106
# Distribution             90
# Engineering              92
# Finance                 102
# Human Resources          91
# Legal                    88
# Marketing                98
# Product                  95
# Sales                    94
# dtype: int64

# %%
Team.first()
# Out:
#                      First Name  Gender  Start Date Last Login Time  Salary  \
# Team
# Business Development    Frances  Female    8/8/2002         6:51 AM  139852
# Client Services           Larry    Male   1/24/1998         4:47 PM  101004
# Distribution            Michael    Male  10/10/2008        11:25 AM   99283
# Engineering              Angela  Female  11/22/2005         6:29 AM   95570
# Finance                   Maria  Female   4/23/1993        11:17 AM  130590
# Human Resources         Brandon    Male   12/1/1980         1:08 AM  112807
# Legal                    Dennis    Male   4/18/1987         1:35 AM  115163
# Marketing               Douglas    Male    8/6/1993        12:42 PM   97308
# Product                    Ruby  Female   8/17/1987         4:20 PM   65476
# Sales                      Gary    Male   1/27/2008        11:40 PM  109831
#
#                       Bonus % Senior Management
# Team
# Business Development    7.524              True
# Client Services         1.389              True
# Distribution            2.665              True
# Engineering            18.523              True
# Finance                11.858             False
# Human Resources        17.492              True
# Legal                  10.125             False
# Marketing               6.945              True
# Product                10.012              True
# Sales                   5.831             False

# %%
Team.last()
# Out:
#                      First Name  Gender  Start Date Last Login Time  Salary  \
# Team
# Business Development      Larry    Male   4/20/2013         4:45 PM   60500
# Client Services           Robin  Female   7/24/1987         1:35 PM  100765
# Distribution              Henry  Female  11/23/2014         6:09 AM  132483
# Engineering                Tina  Female   5/15/1997         3:53 PM   56450
# Finance                 Phillip    Male   1/31/1984         6:30 AM   42392
# Human Resources           Alice  Female   10/5/2004         9:34 AM   47638
# Legal                    Justin    Male   2/10/1991         4:58 PM   38344
# Marketing                George    Male   6/21/2013         5:47 PM   98874
# Product                 Russell    Male   5/20/2013        12:39 PM   96914
# Sales                    Albert    Male   5/15/2012         6:24 PM  129949
#
#                       Bonus % Senior Management
# Team
# Business Development   11.985             False
# Client Services        10.982              True
# Distribution           16.655             False
# Engineering            19.040              True
# Finance                19.675             False
# Human Resources        11.209             False
# Legal                   3.794             False
# Marketing               4.479              True
# Product                 1.421             False
# Sales                  10.169              True
